# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import confusion_matrix
from sklearn.neural_network import MLPClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_curve

# Importo il drugset
file_path = r'C:\Users\nilon\Downloads\Tesina Nilo Netti 307387 e Martino Giovannetti 307480 (1)\Tesina Nilo Netti 307387 e Martino Giovannetti 307480drug_consumption.data'
column_names = ['ID', 'Age', 'Gender', 'Education', 'Country', 'Ethnicity', 'Nscore', 'Escore', 'Oscore', 'Cscore', 'Ascore', 'Impulsive', 'SS', 'Alcohol', 'Amphet', 'Amyl', 'Benzos', 'Caffeine', 'Cannabis', 'Choc', 'Coke', 'Crack', 'Ecstasy', 'Heroin', 'Ketamine', 'Legalh', 'LSD', 'Methadone', 'Mushrooms', 'Nicotine', 'Semeron', 'VSA']
drugs = pd.read_csv(file_path, header=None, names=column_names)

columns_to_drop = ['ID','VSA', 'Semeron', 'Methadone', 'Heroin', 'Ketamine', 'Crack', 'Benzos', 'Legalh', 'Amyl']
drugs = drugs.drop(columns=columns_to_drop)

column_names = ['Age', 'Gender', 'Education', 'Country', 'Ethnicity', 'Nscore', 'Escore', 'Oscore', 'Cscore', 'Ascore', 'Impulsive', 'SS', 'Alcohol', 'Amphet', 'Caffeine', 'Cannabis', 'Choc', 'Coke', 'Ecstasy', 'LSD', 'Mushrooms', 'Nicotine']


# Visualizzo drugset
drugs.head(6)
# Out:
#        Age   Gender  Education  Country  Ethnicity   Nscore   Escore   Oscore  \
# 0  0.49788  0.48246   -0.05921  0.96082    0.12600  0.31287 -0.57545 -0.58331
# 1 -0.07854 -0.48246    1.98437  0.96082   -0.31685 -0.67825  1.93886  1.43533
# 2  0.49788 -0.48246   -0.05921  0.96082   -0.31685 -0.46725  0.80523 -0.84732
# 3 -0.95197  0.48246    1.16365  0.96082   -0.31685 -0.14882 -0.80615 -0.01928
# 4  0.49788  0.48246    1.98437  0.96082   -0.31685  0.73545 -1.63340 -0.45174
# 5  2.59171  0.48246   -1.22751  0.24923   -0.31685 -0.67825 -0.30033 -1.55521
#
#     Cscore   Ascore  ...  Alcohol  Amphet Caffeine Cannabis Choc Coke Ecstasy  \
# 0 -0.91699 -0.00665  ...      CL5     CL2      CL6      CL0  CL5  CL0     CL0
# 1  0.76096 -0.14277  ...      CL5     CL2      CL6      CL4  CL6  CL3     CL4
# 2 -1.62090 -1.01450  ...      CL6     CL0      CL6      CL3  CL4  CL0     CL0
# 3  0.59042  0.58489  ...      CL4     CL0      CL5      CL2  CL4  CL2     CL0
# 4 -0.30172  1.30612  ...      CL4     CL1      CL6      CL3  CL6  CL0     CL1
# 5  2.03972  1.63088  ...      CL2     CL0      CL6      CL0  CL4  CL0     CL0
#
#    LSD Mushrooms Nicotine
# 0  CL0       CL0      CL2
# 1  CL2       CL0      CL4
# 2  CL0       CL1      CL0
# 3  CL0       CL0      CL2
# 4  CL0       CL2      CL2
# 5  CL0       CL0      CL6
#
# [6 rows x 22 columns]

# %%
drugs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1885 entries, 0 to 1884
# Data columns (total 22 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age        1885 non-null   float64
#  1   Gender     1885 non-null   float64
#  2   Education  1885 non-null   float64
#  3   Country    1885 non-null   float64
#  4   Ethnicity  1885 non-null   float64
#  5   Nscore     1885 non-null   float64
#  6   Escore     1885 non-null   float64
#  7   Oscore     1885 non-null   float64
#  8   Cscore     1885 non-null   float64
#  9   Ascore     1885 non-null   float64
#  10  Impulsive  1885 non-null   float64
#  11  SS         1885 non-null   float64
#  12  Alcohol    1885 non-null   object
#  13  Amphet     1885 non-null   object
#  14  Caffeine   1885 non-null   object
#  15  Cannabis   1885 non-null   object
#  16  Choc       1885 non-null   object
#  17  Coke       1885 non-null   object
#  18  Ecstasy    1885 non-null   object
#  19  LSD        1885 non-null   object
#  20  Mushrooms  1885 non-null   object
#  21  Nicotine   1885 non-null   object
# dtypes: float64(12), object(10)
# memory usage: 324.1+ KB

# %%
dizionario = {f"CL{i}" : i for i in range(7)}
print(dizionario)
# Out:
# {'CL0': 0, 'CL1': 1, 'CL2': 2, 'CL3': 3, 'CL4': 4, 'CL5': 5, 'CL6': 6}

# %% [markdown]
# ### Label encoding

# %%
columns_to_map = column_names[12:22]

for i in columns_to_map:
     drugs[i] = drugs[i].map(dizionario)

display(drugs)
# Out:
#           Age   Gender  Education  Country  Ethnicity   Nscore   Escore  \
# 0     0.49788  0.48246   -0.05921  0.96082    0.12600  0.31287 -0.57545
# 1    -0.07854 -0.48246    1.98437  0.96082   -0.31685 -0.67825  1.93886
# 2     0.49788 -0.48246   -0.05921  0.96082   -0.31685 -0.46725  0.80523
# 3    -0.95197  0.48246    1.16365  0.96082   -0.31685 -0.14882 -0.80615
# 4     0.49788  0.48246    1.98437  0.96082   -0.31685  0.73545 -1.63340
# ...       ...      ...        ...      ...        ...      ...      ...
# 1880 -0.95197  0.48246   -0.61113 -0.57009   -0.31685 -1.19430  1.74091
# 1881 -0.95197 -0.48246   -0.61113 -0.57009   -0.31685 -0.24649  1.74091
# 1882 -0.07854  0.48246    0.45468 -0.57009   -0.31685  1.13281 -1.37639
# 1883 -0.95197  0.48246   -0.61113 -0.57009   -0.31685  0.91093 -1.92173
# 1884 -0.95197 -0.48246   -0.61113  0.21128   -0.31685 -0.46725  2.12700
#
#        Oscore   Cscore   Ascore  ...  Alcohol  Amphet  Caffeine  Cannabis  \
# 0    -0.58331 -0.91699 -0.00665  ...        5       2         6         0
# 1     1.43533  0.76096 -0.14277  ...        5       2         6         4
# 2    -0.84732 -1.62090 -1.01450  ...        6       0         6         3
# 3    -0.01928  0.59042  0.58489  ...        4       0         5         2
# 4    -0.45174 -0.30172  1.30612  ...        4       1         6         3
# ...       ...      ...      ...  ...      ...     ...       ...       ...
# 1880  1.88511  0.76096 -1.13788  ...        5       0         4         5
# 1881  0.58331  0.76096 -1.51840  ...        5       0         5         3
# 1882 -1.27553 -1.77200 -1.38502  ...        4       6         6         6
# 1883  0.29338 -1.62090 -2.57309  ...        5       0         6         6
# 1884  1.65653  1.11406  0.41594  ...        4       3         6         3
#
#       Choc  Coke  Ecstasy  LSD  Mushrooms  Nicotine
# 0        5     0        0    0          0         2
# 1        6     3        4    2          0         4
# 2        4     0        0    0          1         0
# 3        4     2        0    0          0         2
# 4        6     0        1    0          2         2
# ...    ...   ...      ...  ...        ...       ...
# 1880     4     0        0    3          0         0
# 1881     4     0        2    5          4         5
# 1882     6     4        4    2          2         6
# 1883     5     0        3    3          3         4
# 1884     6     3        3    3          3         6
#
# [1885 rows x 22 columns]

# %%
drugs.describe()
# Out:
#               Age       Gender    Education      Country    Ethnicity  \
# count  1885.00000  1885.000000  1885.000000  1885.000000  1885.000000
# mean      0.03461    -0.000256    -0.003806     0.355542    -0.309577
# std       0.87836     0.482588     0.950078     0.700335     0.166226
# min      -0.95197    -0.482460    -2.435910    -0.570090    -1.107020
# 25%      -0.95197    -0.482460    -0.611130    -0.570090    -0.316850
# 50%      -0.07854    -0.482460    -0.059210     0.960820    -0.316850
# 75%       0.49788     0.482460     0.454680     0.960820    -0.316850
# max       2.59171     0.482460     1.984370     0.960820     1.907250
#
#             Nscore       Escore       Oscore       Cscore       Ascore  ...  \
# count  1885.000000  1885.000000  1885.000000  1885.000000  1885.000000  ...
# mean      0.000047    -0.000163    -0.000534    -0.000245    -0.000386  ...
# std       0.998106     0.997448     0.996229     0.997440     0.997523  ...
# min      -3.464360    -3.273930    -3.273930    -3.464360    -3.464360  ...
# 25%      -0.678250    -0.695090    -0.717270    -0.606330    -0.652530  ...
# 50%       0.042570     0.003320    -0.019280    -0.017290    -0.006650  ...
# 75%       0.629670     0.637790     0.723300     0.760960     0.584890  ...
# max       3.273930     3.273930     2.901610     3.464360     3.464360  ...
#
#            Alcohol       Amphet     Caffeine     Cannabis         Choc  \
# count  1885.000000  1885.000000  1885.000000  1885.000000  1885.000000
# mean      4.635013     1.340584     5.483820     2.989390     5.106631
# std       1.331253     1.783587     1.114648     2.287438     1.089315
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       4.000000     0.000000     5.000000     1.000000     5.000000
# 50%       5.000000     0.000000     6.000000     3.000000     5.000000
# 75%       6.000000     2.000000     6.000000     5.000000     6.000000
# max       6.000000     6.000000     6.000000     6.000000     6.000000
#
#               Coke      Ecstasy          LSD    Mushrooms     Nicotine
# count  1885.000000  1885.000000  1885.000000  1885.000000  1885.000000
# mean      1.161273     1.314058     1.061538     1.187268     3.200531
# std       1.513031     1.647567     1.491103     1.466341     2.413932
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     1.000000
# 50%       0.000000     0.000000     0.000000     0.000000     3.000000
# 75%       2.000000     3.000000     2.000000     2.000000     6.000000
# max       6.000000     6.000000     6.000000     6.000000     6.000000
#
# [8 rows x 22 columns]

# %% [markdown]
# Dimensioni dataset

# %%
M,N = drugs.shape
print(f"Il dataset ha {M} righe e {N} colonne")
# Out:
# Il dataset ha 1885 righe e 22 colonne

# %% [markdown]
# Controllo bilanciamento del dataset, plotto le frequenze

# %%
frequenze = {col: drugs[col].value_counts().sort_index() for col in columns_to_map}
frequenze_df = pd.DataFrame(frequenze).fillna(0).astype(int)
frequenze_df.plot(kind='bar', figsize=(15, 8), width=0.8)
plt.title('Frequenze delle classi di utilizzo per ogni droga')
plt.xlabel('Classi di utilizzo')
plt.ylabel('Persone')
plt.legend(title='Droghe', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Calcolo delle frequenze relative
try:
    frequenze_relative = frequenze_df / M
    display(frequenze_relative.style.format('{:.2%}').set_caption('Frequenze Relative'))
except Exception as e:
    print(f"Errore durante il calcolo o la visualizzazione delle frequenze relative: {e}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_83b1b">
#   <caption>Frequenze Relative</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83b1b_level0_col0" class="col_heading level0 col0" >Alcohol</th>
#       <th id="T_83b1b_level0_col1" class="col_heading level0 col1" >Amphet</th>
#       <th id="T_83b1b_level0_col2" class="col_heading level0 col2" >Caffeine</th>
#       <th id="T_83b1b_level0_col3" class="col_heading level0 col3" >Cannabis</th>
#       <th id="T_83b1b_level0_col4" class="col_heading level0 col4" >Choc</th>
#       <th id="T_83b1b_level0_col5" class="col_heading level0 col5" >Coke</th>
#       <th id="T_83b1b_level0_col6" class="col_heading level0 col6" >Ecstasy</th>
#       <th id="T_83b1b_level0_col7" class="col_heading level0 col7" >LSD</th>
#       <th id="T_83b1b_level0_col8" class="col_heading level0 col8" >Mushrooms</th>
#       <th id="T_83b1b_level0_col9" class="col_heading level0 col9" >Nicotine</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83b1b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_83b1b_row0_col0" class="data row0 col0" >1.80%</td>
#       <td id="T_83b1b_row0_col1" class="data row0 col1" >51.78%</td>
#       <td id="T_83b1b_row0_col2" class="data row0 col2" >1.43%</td>
#       <td id="T_83b1b_row0_col3" class="data row0 col3" >21.91%</td>
#       <td id="T_83b1b_row0_col4" class="data row0 col4" >1.70%</td>
#       <td id="T_83b1b_row0_col5" class="data row0 col5" >55.07%</td>
#       <td id="T_83b1b_row0_col6" class="data row0 col6" >54.16%</td>
#       <td id="T_83b1b_row0_col7" class="data row0 col7" >56.71%</td>
#       <td id="T_83b1b_row0_col8" class="data row0 col8" >52.10%</td>
#       <td id="T_83b1b_row0_col9" class="data row0 col9" >22.71%</td>
#     </tr>
#     <tr>
#       <th id="T_83b1b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_83b1b_row1_col0" class="data row1 col0" >1.80%</td>
#       <td id="T_83b1b_row1_col1" class="data row1 col1" >12.20%</td>
#       <td id="T_83b1b_row1_col2" class="data row1 col2" >0.53%</td>
#       <td id="T_83b1b_row1_col3" class="data row1 col3" >10.98%</td>
#       <td id="T_83b1b_row1_col4" class="data row1 col4" >0.16%</td>
#       <td id="T_83b1b_row1_col5" class="data row1 col5" >8.49%</td>
#       <td id="T_83b1b_row1_col6" class="data row1 col6" >5.99%</td>
#       <td id="T_83b1b_row1_col7" class="data row1 col7" >13.74%</td>
#       <td id="T_83b1b_row1_col8" class="data row1 col8" >11.09%</td>
#       <td id="T_83b1b_row1_col9" class="data row1 col9" >10.24%</td>
#     </tr>
#     <tr>
#       <th id="T_83b1b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_83b1b_row2_col0" class="data row2 col0" >3.61%</td>
#       <td id="T_83b1b_row2_col1" class="data row2 col1" >12.89%</td>
#       <td id="T_83b1b_row2_col2" class="data row2 col2" >1.27%</td>
#       <td id="T_83b1b_row2_col3" class="data row2 col3" >14.11%</td>
#       <td id="T_83b1b_row2_col4" class="data row2 col4" >0.53%</td>
#       <td id="T_83b1b_row2_col5" class="data row2 col5" >14.32%</td>
#       <td id="T_83b1b_row2_col6" class="data row2 col6" >12.41%</td>
#       <td id="T_83b1b_row2_col7" class="data row2 col7" >9.39%</td>
#       <td id="T_83b1b_row2_col8" class="data row2 col8" >13.79%</td>
#       <td id="T_83b1b_row2_col9" class="data row2 col9" >10.82%</td>
#     </tr>
#     <tr>
#       <th id="T_83b1b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_83b1b_row3_col0" class="data row3 col0" >10.50%</td>
#       <td id="T_83b1b_row3_col1" class="data row3 col1" >10.50%</td>
#       <td id="T_83b1b_row3_col2" class="data row3 col2" >3.18%</td>
#       <td id="T_83b1b_row3_col3" class="data row3 col3" >11.19%</td>
#       <td id="T_83b1b_row3_col4" class="data row3 col4" >2.86%</td>
#       <td id="T_83b1b_row3_col5" class="data row3 col5" >13.69%</td>
#       <td id="T_83b1b_row3_col6" class="data row3 col6" >14.69%</td>
#       <td id="T_83b1b_row3_col7" class="data row3 col7" >11.35%</td>
#       <td id="T_83b1b_row3_col8" class="data row3 col8" >14.59%</td>
#       <td id="T_83b1b_row3_col9" class="data row3 col9" >9.81%</td>
#     </tr>
#     <tr>
#       <th id="T_83b1b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_83b1b_row4_col0" class="data row4 col0" >15.23%</td>
#       <td id="T_83b1b_row4_col1" class="data row4 col1" >3.98%</td>
#       <td id="T_83b1b_row4_col2" class="data row4 col2" >5.62%</td>
#       <td id="T_83b1b_row4_col3" class="data row4 col3" >7.43%</td>
#       <td id="T_83b1b_row4_col4" class="data row4 col4" >15.70%</td>
#       <td id="T_83b1b_row4_col5" class="data row4 col5" >5.25%</td>
#       <td id="T_83b1b_row4_col6" class="data row4 col6" >8.28%</td>
#       <td id="T_83b1b_row4_col7" class="data row4 col7" >5.15%</td>
#       <td id="T_83b1b_row4_col8" class="data row4 col8" >6.10%</td>
#       <td id="T_83b1b_row4_col9" class="data row4 col9" >5.73%</td>
#     </tr>
#     <tr>
#       <th id="T_83b1b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_83b1b_row5_col0" class="data row5 col0" >40.27%</td>
#       <td id="T_83b1b_row5_col1" class="data row5 col1" >3.24%</td>
#       <td id="T_83b1b_row5_col2" class="data row5 col2" >14.48%</td>
#       <td id="T_83b1b_row5_col3" class="data row5 col3" >9.81%</td>
#       <td id="T_83b1b_row5_col4" class="data row5 col4" >36.23%</td>
#       <td id="T_83b1b_row5_col5" class="data row5 col5" >2.18%</td>
#       <td id="T_83b1b_row5_col6" class="data row5 col6" >3.34%</td>
#       <td id="T_83b1b_row5_col7" class="data row5 col7" >2.97%</td>
#       <td id="T_83b1b_row5_col8" class="data row5 col8" >2.12%</td>
#       <td id="T_83b1b_row5_col9" class="data row5 col9" >8.33%</td>
#     </tr>
#     <tr>
#       <th id="T_83b1b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_83b1b_row6_col0" class="data row6 col0" >26.79%</td>
#       <td id="T_83b1b_row6_col1" class="data row6 col1" >5.41%</td>
#       <td id="T_83b1b_row6_col2" class="data row6 col2" >73.47%</td>
#       <td id="T_83b1b_row6_col3" class="data row6 col3" >24.56%</td>
#       <td id="T_83b1b_row6_col4" class="data row6 col4" >42.81%</td>
#       <td id="T_83b1b_row6_col5" class="data row6 col5" >1.01%</td>
#       <td id="T_83b1b_row6_col6" class="data row6 col6" >1.11%</td>
#       <td id="T_83b1b_row6_col7" class="data row6 col7" >0.69%</td>
#       <td id="T_83b1b_row6_col8" class="data row6 col8" >0.21%</td>
#       <td id="T_83b1b_row6_col9" class="data row6 col9" >32.36%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Analisi della distribuzione delle variabili numeriche con istogrammi

# %%
# Istogrammi per le variabili numeriche con layout migliorato
drugs.hist(figsize=(15, 10), bins=20, color='skyblue', edgecolor='black')
plt.suptitle("Distribuzione delle variabili numeriche", y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# Divisione di training + validation set

# %%
feature_columns = ['Age', 'Gender', 'Education', 'Country', 'Ethnicity', 
                'Nscore', 'Escore', 'Oscore', 'Cscore', 'Ascore', 'Impulsive', 'SS']
target_columns = columns_to_map  # Le droghe che hai già mappato


# Estraiamo features e target
X = drugs[feature_columns].copy()
y = drugs[target_columns].copy()

print(f"\nShape features (X): {X.shape}")
print(f"Shape target (y): {y.shape}")

# Divido test set e validation + training set
test_size=0.15
validation_size = 0.2
training_size = 0.65

X_trainval, X_test, y_trainval, y_test = train_test_split(
X, y, 
test_size=test_size,
random_state=42,
shuffle=True
)
# Out:
# Shape features (X): (1885, 12)
# Shape target (y): (1885, 10)

# %% [markdown]
# ## Principal Component Analysis (PCA)
#
# L'idea alla base della PCA è quella di diminuire le dimensioni dello spazio delle features, minimizzando la perdita di varianza (cioè informazione) dei dati.
# I nostri dati vengono pensati come punti in uno spazio $\mathbb{R}^d$ dove $d$ è il numero di features che li caratterizzano.
# In generale è computazionalmente dispendioso lavorare in spazi di alte dimensioni, inoltre i dati tendono a diventare molto sparsi ed alcuni algoritmi perdono di significato ed efficienza.
#
# ### Intuizione geometrica
#
# La PCA trova la direzione di **massima varianza** nei dati. In 2D, questo significa trovare la retta che meglio approssima i dati minimizzando gli errori di proiezione.
#
# La direzione ottimale per la proiezione è quella lungo cui i dati hanno la **varianza più grande**. Preservare la direzione con più varianza significa mantenere il massimo dell'informazione.
#
# ### Algebra lineare per la derivazione
#
# Consideriamo uno spazio $V$ di dimensione $d$ e un sottospazio $W$ di dimensione $k < d$.
# Possiamo sempre trovare un set di $k$ vettori $\{e_1, e_2, \ldots, e_k\}$ che formano una **base ortonormale** per $W$:
# $$\langle e_i, e_j \rangle = \delta_{ij} = \begin{cases}
# 1 & \text{se } i = j \\
# 0 & \text{se } i \neq j
# \end{cases}$$
#
# Qualsiasi vettore in $W$ può essere scritto come:
# $$\sum_{i=1}^k \alpha_i e_i$$
#
# ### Derivazione formale della PCA
#
# Sia $D = \{x_1, x_2, \dots, x_n\} \subset \mathbb{R}^d$ il dataset.
#
# #### Passo 1: Centrare i dati
#
# Per derivare la PCA, è conveniente proiettare su un sottospazio $W$ che passa per l'origine. Quindi spostiamo il centro di massa all'origine:
# $$x_j' = x_j - \mu, \quad \text{dove } \mu = \frac{1}{n}\sum_{j=1}^n x_j$$
#
# #### Passo 2: Formulazione del problema
#
# Vogliamo trovare la rappresentazione più accurata dei dati $D = \{x_1, x_2, \ldots, x_n\}$ in un sottospazio $W$ di dimensione $k < d$.
#
# Sia $\{e_1, e_2, \ldots, e_k\}$ la base ortonormale per $W$. Ogni $x_j$ sarà rappresentato da un vettore in $W$:
# $$\hat{x}_j = \sum_{i=1}^k \alpha_{ji} e_i$$
#
# L'errore per un singolo punto è:
# $$\text{errore}_j = \left\|x_j - \sum_{i=1}^k \alpha_{ji} e_i\right\|^2$$
#
# #### Passo 3: Errore totale
#
# L'errore totale per tutti i dati è:
# $$J(e_1, \ldots, e_k, \alpha_{11}, \ldots, \alpha_{nk}) = \sum_{j=1}^n \left\|x_j - \sum_{i=1}^k \alpha_{ji} e_i\right\|^2$$
#
# #### Passo 4: Ottimizzazione rispetto ai coefficienti
#
# Per minimizzare $J$, deriviamo rispetto ad $\alpha_{ml}$:
# $$\frac{\partial J}{\partial \alpha_{ml}} = -2e_l^T x_m + 2\alpha_{ml} = 0$$
#
# Da cui otteniamo il valore ottimale:
# $$\alpha_{ml} = e_l^T x_m$$
#
# #### Passo 5: Sostituzione e semplificazione
#
# Sostituendo i valori ottimali di $\alpha_{ml}$ in $J$:
# $$J = \sum_{j=1}^n \|x_j\|^2 - \sum_{j=1}^n \sum_{i=1}^k (e_i^T x_j)^2$$
#
# Usando $(a^T b)^2 = (a^T b)(a^T b) = b^T(aa^T)b$:
# $$J = \sum_{j=1}^n \|x_j\|^2 - \sum_{j=1}^n \sum_{i=1}^k e_i^T(x_j x_j^T)e_i$$
#
# #### Passo 6: Matrice di scatter
#
# Definiamo la **matrice di scatter**:
# $$S = \sum_{j=1}^n x_j x_j^T$$
#
# **Nota:** $S$ è $n-1$ volte la matrice di covarianza campionaria.
#
# Sostituendo nella formula dell'errore:
# $$J = \sum_{j=1}^n \|x_j\|^2 - \sum_{i=1}^k e_i^T S e_i$$
#
# Poiché il primo termine $\sum_{j=1}^n \|x_j\|^2$ è costante (non dipende dagli $e_i$), **minimizzare** $J$ equivale a **massimizzare**:
# $$\sum_{i=1}^k e_i^T S e_i$$
#
# #### Passo 7: Vincoli ortonormalità e moltiplicatori di Lagrange
#
# Il nostro problema di ottimizzazione è:
# - **Massimizzare:** $\sum_{i=1}^k e_i^T S e_i$
# - **Soggetto ai vincoli:** $e_i^T e_i = 1$ per ogni $i = 1, \ldots, k$
#
# Questo è un problema di **ottimizzazione vincolata**. I **moltiplicatori di Lagrange** sono una tecnica per trasformare un problema vincolato in uno non vincolato.
#
# Per ogni vincolo $g_i(e_i) = e_i^T e_i - 1 = 0$, introduciamo un moltiplicatore $\lambda_i$ e costruiamo la **funzione Lagrangiana**:
#
# $$u(e_1, \ldots, e_k, \lambda_1, \ldots, \lambda_k) = \sum_{i=1}^k e_i^T S e_i - \sum_{i=1}^k \lambda_i(e_i^T e_i - 1)$$
#
# La funzione $u$ combina:
# - La **funzione obiettivo** da massimizzare: $\sum_{i=1}^k e_i^T S e_i$
# - I **vincoli penalizzati** dai moltiplicatori: $-\sum_{i=1}^k \lambda_i(e_i^T e_i - 1)$
#
# Derivando rispetto ad $e_m$:
# $$\frac{\partial u}{\partial e_m} = 2Se_m - 2\lambda_m e_m = 0$$
#
# Da cui otteniamo:
# $$Se_m = \lambda_m e_m$$
#
# Questa è l'**equazione agli autovalori**: gli $e_m$ ottimali sono gli **autovettori** di $S$ e i $\lambda_m$ sono i corrispondenti **autovalori**.
# #### Passo 8: Condizioni di ottimalità e scelta degli autovettori
#
# Dall'equazione agli autovalori ottenuta al passo 7:
# $$Se_m = \lambda_m e_m$$
#
# abbiamo dimostrato che gli $e_m$ ottimali devono essere **autovettori** di $S$ con autovalori $\lambda_m$.
#
# **Ma quali autovettori scegliere?** La matrice $S$ ha $d$ autovettori, ma noi ne vogliamo solo $k < d$.
#
# Sostituiamo $Se_m = \lambda_m e_m$ nella funzione obiettivo. Ricordiamo che vogliamo massimizzare:
# $$\sum_{i=1}^k e_i^T S e_i$$
#
# Per ogni termine:
# $$e_i^T S e_i = e_i^T (\lambda_i e_i) = \lambda_i (e_i^T e_i) = \lambda_i \cdot 1 = \lambda_i$$
#
# dove abbiamo usato il vincolo di normalità $e_i^T e_i = 1$.
#
# Quindi la funzione obiettivo diventa:
# $$\sum_{i=1}^k e_i^T S e_i = \sum_{i=1}^k \lambda_i$$
#
# **Conclusione:** Per **massimizzare** $\sum_{i=1}^k \lambda_i$, dobbiamo scegliere i $k$ **autovalori più grandi**.
#
# **Soluzione finale:** Ordiniamo gli autovalori in ordine decrescente:
# $$\lambda_1 \geq \lambda_2 \geq \ldots \geq \lambda_d$$
#
# e prendiamo gli autovettori $e_1, e_2, \ldots, e_k$ corrispondenti ai **primi $k$ autovalori più grandi**.
#
# Sostituendo nell'errore originale:
# $$J = \sum_{j=1}^n \|x_j\|^2 - \sum_{i=1}^k \lambda_i$$
#
# Massimizzare $\sum_{i=1}^k \lambda_i$ equivale a **minimizzare** l'errore $J$.
#
# ### Interpretazione e significato
#
# **Componenti principali:** I coefficienti $\alpha_{mi} = x_m^T e_i$ sono chiamati **componenti principali**.
#
# **Varianza spiegata:** La varianza nella direzione dell'$i$-esimo componente principale è $\lambda_i$.
#
# **Importanza dei componenti:** I componenti sono ordinati per importanza. I primi $k$ componenti più importanti forniscono la migliore approssimazione $k$-dimensionale di $x_i$.
#
# ### Trasformazione delle coordinate
#
# **Matrice di proiezione:** Sia $E = [e_1 \quad e_2 \quad \cdots \quad e_k]$.
#
# **Trasformazione:** La rappresentazione $k$-dimensionale è:
# $$y = E^T x$$
#
# Sotto $E^T$, gli autovettori diventano la base standard:
# $$E^T e_i = \begin{bmatrix} 0 \\ \vdots \\ 1 \\ \vdots \\ 0 \end{bmatrix} \leftarrow \text{posizione } i$$
#
# ### Ricetta PCA completa
#
# Dati $D = \{x_1, x_2, \ldots, x_n\}$ con $x_i \in \mathbb{R}^d$. Riduzione a dimensione $k$:
#
# 1. **Calcola la media campionaria:** $\hat{\mu} = \frac{1}{n}\sum_{i=1}^n x_i$
#
# 2. **Centra i dati:** $z_i = x_i - \hat{\mu}$
#
# 3. **Calcola la matrice di scatter:** $S = \sum_{i=1}^n z_i z_i^T$
#
# 4. **Calcola autovettori:** Trova $e_1, e_2, \ldots, e_k$ corrispondenti ai $k$ autovalori più grandi di $S$
#
# 5. **Forma la matrice di proiezione:** $E = [e_1 \quad e_2 \quad \cdots \quad e_k]$
#
# 6. **Trasforma i dati:** $y = E^T z$ è la rappresentazione $k$-dimensionale più vicina a $x$
#
# ### Regola pratica per la scelta di $k$
#
# Mantieni abbastanza componenti per spiegare l'85% della variazione:
# $$\frac{\sum_{j=1}^k \lambda_j}{\sum_{j=1}^d \lambda_j} \geq 0.85$$

# %% [markdown]
# Tuttavia nel nostro caso, eseguire la PCA non è fondamentale a fini pratici, esserndo lo spazio delle features di sole 12 dimensioni. Ci limiteremo ad eseguire questa tecnica al solo fine di esplorare il dataset, e comprendere quali di esse sono più impoattanti al fine di massimizzare l'imìnformazione contenuta nei dati.

# %%
X_trainval_non_scaled = X_trainval.copy()
X_test_non_scaled = X_test.copy()

scaler = StandardScaler()

X_trainval = scaler.fit_transform(X_trainval)
X_test = scaler.transform(X_test)


pca = PCA(0.85)
pca.fit(X_trainval)



display(pd.DataFrame({'numero di componenti mantenute' : [pca.n_components_], 'varianza spiegata': [pca.explained_variance_ratio_.sum()]}))
for i, var in enumerate(pca.explained_variance_ratio_):
    print(f"Componente {i+1}: {var:.4f} varianza spiegata")

X_trainval = X_trainval.copy()
X_trainval_pca = pca.transform(X_trainval)

plt.figure(figsize=(10, 5))
plt.plot(np.cumsum(pca.explained_variance_ratio_), marker='o')
plt.xlabel('Numero di componenti principali')
plt.ylabel('Varianza cumulativa spiegata')
plt.title('Varianza cumulativa con l\'aumentare delle componenti')
plt.xticks(range(pca.n_components_), range(1, pca.n_components_+1))
plt.grid()
plt.show()
# Out:
#    numero di componenti mantenute  varianza spiegata
# 0                               8           0.851567
# Componente 1: 0.2429 varianza spiegata
# Componente 2: 0.1551 varianza spiegata
# Componente 3: 0.0946 varianza spiegata
# Componente 4: 0.0890 varianza spiegata
# Componente 5: 0.0802 varianza spiegata
# Componente 6: 0.0713 varianza spiegata
# Componente 7: 0.0636 varianza spiegata
# Componente 8: 0.0548 varianza spiegata

# %%
# Mostriamo i contributi delle features alle prime due componenti principali

feature_names = ['Age', 'Gender', 'Education', 'Country', 'Ethnicity', 
                'Nscore', 'Escore', 'Oscore', 'Cscore', 'Ascore', 'Impulsive', 'SS']

contributions_df = pd.DataFrame({
    'Feature': feature_names,
    'PC1_Weight': pca.components_[0],
    'PC2_Weight': pca.components_[1],
    'PC1_Abs': np.abs(pca.components_[0]),
    'PC2_Abs': np.abs(pca.components_[1])
})

contributions_df = contributions_df.sort_values('PC1_Abs', ascending=True)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 8))

colors_pc1 = ['red' if x < 0 else 'darkblue' for x in contributions_df['PC1_Weight']]
bars1 = ax1.barh(range(len(contributions_df)), contributions_df['PC1_Weight'], 
                 color=colors_pc1, alpha=0.7, edgecolor='black', linewidth=0.5)

ax1.set_yticks(range(len(contributions_df)))
ax1.set_yticklabels(contributions_df['Feature'])
ax1.set_xlabel('Peso della Feature')
ax1.set_title(f'Contributi Features a PC1\n({pca.explained_variance_ratio_[0]*100:.1f}% varianza spiegata)', 
              fontsize=14, fontweight='bold')
ax1.grid(True, alpha=0.3, axis='x')
ax1.axvline(x=0, color='black', linewidth=0.8)

for i, (bar, value) in enumerate(zip(bars1, contributions_df['PC1_Weight'])):
    ax1.text(value + (0.01 if value >= 0 else -0.01), i, f'{value:.3f}', 
             va='center', ha='left' if value >= 0 else 'right', fontsize=9)

contributions_df_pc2 = contributions_df.sort_values('PC2_Abs', ascending=True)
colors_pc2 = ['red' if x < 0 else 'darkgreen' for x in contributions_df_pc2['PC2_Weight']]
bars2 = ax2.barh(range(len(contributions_df_pc2)), contributions_df_pc2['PC2_Weight'], 
                 color=colors_pc2, alpha=0.7, edgecolor='black', linewidth=0.5)

ax2.set_yticks(range(len(contributions_df_pc2)))
ax2.set_yticklabels(contributions_df_pc2['Feature'])
ax2.set_xlabel('Peso della Feature')
ax2.set_title(f'Contributi Features a PC2\n({pca.explained_variance_ratio_[1]*100:.1f}% varianza spiegata)', 
              fontsize=14, fontweight='bold')
ax2.grid(True, alpha=0.3, axis='x')
ax2.axvline(x=0, color='black', linewidth=0.8)

for i, (bar, value) in enumerate(zip(bars2, contributions_df_pc2['PC2_Weight'])):
    ax2.text(value + (0.01 if value >= 0 else -0.01), i, f'{value:.3f}', 
             va='center', ha='left' if value >= 0 else 'right', fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Neural Networks e Addestramento
#
# ## Cos'è un Multi-Layer Perceptron (MLP)
#
# Un **Multi-Layer Perceptron (MLP)** è una rete neurale artificiale che appartiene alla famiglia delle reti **feed-forward**. È composta da:
#
# - **Layer di input** ($l=0$): riceve i dati di ingresso
# - **Layer nascosti** (hidden layers): elaborano le informazioni attraverso trasformazioni non lineari
# - **Layer di output** ($l=L$): produce le predizioni finali
#
# ### Struttura matematica
#
# Ogni layer $l$ è caratterizzato da:
# - **Trasformazione lineare**: $\mathbf{z}_l = \mathbf{W}_l \mathbf{a}_{l-1} + \mathbf{b}_l$
# - **Funzione di attivazione**: $\mathbf{a}_l = S_l(\mathbf{z}_l)$
#
# dove $\mathbf{W}_l$ sono i pesi, $\mathbf{b}_l$ i bias, e $S_l$ la funzione di attivazione.
#
# L'output finale è ottenuto tramite **composizione di funzioni**:
# $$\mathbf{g}(\mathbf{x}) = S_L \circ M_L \circ \cdots \circ S_2 \circ M_2 \circ S_1 \circ M_1(\mathbf{x})$$
#
# dove $M_l(\mathbf{z}) = \mathbf{W}_l \mathbf{z} + \mathbf{b}_l$.
#
# ### A cosa serve
#
# L'MLP è un **approssimatore universale** che può:
# - **Classificazione**: distinguere tra diverse classi (es. riconoscimento immagini)
# - **Regressione**: predire valori continui (es. prezzi immobiliari)
# - **Riconoscimento di pattern**: identificare strutture complesse nei dati
#
# La sua forza sta nella capacità di apprendere **relazioni non lineari** attraverso la composizione di trasformazioni semplici.
#
# ## Funzioni di Attivazione
#
# Le funzioni di attivazione introducono **non linearità** nella rete:
#
# - **ReLU**: $f(z) = \max(0, z)$ - più usata, evita il problema della saturazione
# - **Sigmoid**: $f(z) = \frac{1}{1 + e^{-z}}$ - output tra 0 e 1
# - **Softmax**: per classificazione multi-classe, produce probabilità
#
# ## Back-propagation: L'Algoritmo Fondamentale
#
# La **back-propagation** è l'algoritmo che permette di calcolare efficientemente i gradienti necessari per l'addestramento delle reti neurali.
#
# ### Il Problema
#
# Vogliamo minimizzare la **loss function**:
# $$L(\boldsymbol{\theta}) = \frac{1}{n}\sum_{i=1}^n \text{Loss}(\mathbf{y}_i, \mathbf{g}(\mathbf{x}_i | \boldsymbol{\theta}))$$
#
# dove $\boldsymbol{\theta} = \{\mathbf{W}_l, \mathbf{b}_l\}_{l=1}^L$ sono tutti i parametri della rete.
#
# Per applicare la **gradient descent**, abbiamo bisogno di:
# $$\frac{\partial L}{\partial \mathbf{W}_l} \quad \text{e} \quad \frac{\partial L}{\partial \mathbf{b}_l} \quad \text{per ogni layer } l$$
#
# #### Come calcolarli:
#
# **Siano a e z i vettori ottenuti durante la feed-forward propagation:**
#
# $$\mathbf{x} \rightarrow \mathbf{z}_1 \rightarrow \mathbf{a}_1 \rightarrow \mathbf{z}_2 \rightarrow \mathbf{a}_2 \rightarrow \cdots \rightarrow \mathbf{z}_L \rightarrow \mathbf{a}_L = \mathbf{g}(\mathbf{x})$$
#
# Allora  i gradienti sono:
# $$\frac{\partial L}{\partial \mathbf{W}_l} = \boldsymbol{\delta}_l \mathbf{a}_{l-1}^T \quad \text{e} \quad \frac{\partial L}{\partial \mathbf{b}_l} = \boldsymbol{\delta}_l$$
#
# Dove: $$\boldsymbol{\delta}_l = \frac{\partial L}{\partial \mathbf{z}_l}$$  è calcolato ricorsivamente a partire da L:
#
# $$\boldsymbol{\delta}_L = \frac{\partial S_L}{\partial \mathbf{z}_L} \frac{\partial L}{\partial \mathbf{g}}$$
# e
# $$\boldsymbol{\delta}_{l} = \mathbf{D}_{l} \mathbf{W}_{l+1}^T \boldsymbol{\delta}_{l+1}$$
# dove $\mathbf{D}_l = \text{diag}(S'(\mathbf{z}_{l,1}), \ldots, S'(\mathbf{z}_{l,p_l}))$.
#
# ## Algoritmi di Ottimizzazione
#
# ### Gradient Descent (Batch)
# $$\boldsymbol{\theta}_{t+1} = \boldsymbol{\theta}_t - \alpha \nabla L(\boldsymbol{\theta}_t)$$
#
# Il **Gradient Descent classico** (o Batch Gradient Descent) calcola il gradiente usando **tutto il dataset**:
# $$\nabla L(\boldsymbol{\theta}) = \frac{1}{n}\sum_{i=1}^n \nabla \text{Loss}(\mathbf{y}_i, \mathbf{g}(\mathbf{x}_i | \boldsymbol{\theta}))$$
#
# **Vantaggi:**
# - Convergenza **stabile** e **deterministica**
# - Gradiente è la direzione di discesa **ottimale**
# - Buone proprietà teoriche di convergenza
#
# **Svantaggi:**
# - **Lento** per dataset grandi (milioni di esempi)
# - Richiede calcolare la loss su **tutti** gli esempi ad ogni iterazione
#
# ### Stochastic Gradient Descent (SGD)
# Invece di usare tutto il dataset, usa **mini-batch** di dimensione $N \ll n$:
# $$\nabla L(\boldsymbol{\theta}) \approx \frac{1}{N}\sum_{i \in \text{batch}} \nabla \text{Loss}(\mathbf{y}_i, \mathbf{g}(\mathbf{x}_i | \boldsymbol{\theta}))$$
#
# **Come funziona:**
# 1. **Stocasticità**: mescola casualmente il dataset
# 2. **Partizionamento**: divide in mini-batch di dimensione $N$ (es. 32, 64, 128)
# 3. **Aggiornamento**: per ogni mini-batch calcola gradiente e aggiorna pesi
# 4. **Epoca completa**: quando tutti i mini-batch sono stati processati
#
# **Vantaggi:**
# - **Velocità**: aggiornamenti frequenti accelerano la convergenza
# - **Memoria efficiente**: processa solo $N$ esempi alla volta
# - **Regolarizzazione implicita**: il "rumore" aiuta a evitare minimi locali
#
# **Svantaggi:**
# - **Convergenza rumorosa**: oscillazioni attorno al minimo
#
# ## Parametri di Controllo dell'Addestramento
#
# ### Epoche Massime (`max_iter`)
# - **Definizione**: numero massimo di passaggi completi attraverso il training set
# - **Scopo**: evitare addestramento infinito
#
# ### Learning Rate (`learning_rate_init`)
# - **Definizione**: dimensione del passo $\alpha$ nell'aggiornamento dei pesi
# - **Effetto**:
#   - Troppo alto → instabilità, oscillazioni
#   - Troppo basso → convergenza molto lenta
# - **Valori tipici**: 0.001-0.1
#
# ### Patience (`n_iter_no_change`)
# - **Definizione**: numero di epoche da aspettare senza miglioramento prima di fermarsi
# - **Scopo**: evitare overfitting
# - **Come funziona**:
#   - Monitora la loss sul validation set dopo ogni epoca
#   - Se non migliora per `patience` epoche consecutive → **STOP**
#   - Previene che la rete "memorizzi" il training set
#
# ### Tolerance (`tol`)
# - **Definizione**: soglia minima di miglioramento per considerare significativo un progresso
# - **Scopo**: evitare micro-oscillazioni e dichiarare convergenza
# - **Matematicamente**: se $|L_{t} - L_{t-1}| < \text{tol}$ → convergenza
#
# ## Prevenzione dell'Overfitting
#
# ### Early Stopping
# Ferma l'addestramento quando:
# - La validation loss smette di migliorare (patience)
# - Il gap tra training e validation loss aumenta troppo
#
# ### Regularization
# - **L1/L2 regularization**: $L(\boldsymbol{\theta}) + \lambda \|\boldsymbol{\theta}\|^2$
# - **Dropout**: disattiva casualmente alcuni neuroni durante l'addestramento
#
# ### Cosa Succede Internamente a mlpClassifier
#
# 1. **Inizializzazione**: pesi casuali per $\mathbf{W}_l, \mathbf{b}_l$
# 2. **Per ogni epoca**:
#    - **Forward pass**: calcola predizioni per tutto il training set
#    - **Back-propagation**: calcola gradienti $\frac{\partial L}{\partial \mathbf{W}_l}, \frac{\partial L}{\partial \mathbf{b}_l}$
#    - **Update**: $\mathbf{W}_l \leftarrow \mathbf{W}_l - \alpha \frac{\partial L}{\partial \mathbf{W}_l}$
#    - **Validation**: valuta performance su validation set
#    - **Early stopping check**: se non migliora per `patience` epoche → stop

# %% [markdown]
# Ciò che faremo adesso sarà addestrare un mlp **multiclasse**, cioè una struttura leggermente più complessa, contenente un mlp per ciascuna sostanza stupefacente, 10 in totale. L'output sarà dunque un vettore di 10 elementi, ciascuno dei quali rappresenta il risultato degli mlp interni.
# Tuttavia vedremo che il riaultato di questo multi-mlp sarà scadente poichè il dataset è **estremamente sbilanciato** per maggior parte dei target, perciò il modello impara a predire sempre la risposta "più conveniente" cioè la classe nettamente maggioritaria.

# %%
hidden_layer_sizes = [16]
activation = 'relu'
patience = 75
max_epochs = 5000
batch_size = 8

mlp1 = MLPClassifier(
    hidden_layer_sizes=hidden_layer_sizes,
    activation=activation,
    max_iter=max_epochs,
    batch_size=batch_size,
    verbose=True,
    early_stopping=True,
    validation_fraction=validation_size,
    n_iter_no_change=patience,
    random_state=42,
    solver='adam',
)

multi_target_mlp1 = MultiOutputClassifier(mlp1)
multi_target_mlp1.fit(X_trainval, y_trainval)
# Out:
# Iteration 1, loss = 1.97817880
# Validation score: 0.193146
# Iteration 2, loss = 1.63973272
# Validation score: 0.299065
# Iteration 3, loss = 1.53973014
# Validation score: 0.376947
# Iteration 4, loss = 1.50039009
# Validation score: 0.380062
# Iteration 5, loss = 1.47796188
# Validation score: 0.383178
# Iteration 6, loss = 1.46164300
# Validation score: 0.376947
# Iteration 7, loss = 1.45005020
# Validation score: 0.373832
# Iteration 8, loss = 1.44109775
# Validation score: 0.376947
# Iteration 9, loss = 1.43370914
# Validation score: 0.386293
# Iteration 10, loss = 1.42795460
# Validation score: 0.389408
# Iteration 11, loss = 1.42240114
# Validation score: 0.383178
# Iteration 12, loss = 1.41741041
# Validation score: 0.389408
# Iteration 13, loss = 1.41332979
# Validation score: 0.383178
# Iteration 14, loss = 1.40974794
# Validation score: 0.367601
# Iteration 15, loss = 1.40559203
# Validation score: 0.370717
# Iteration 16, loss = 1.40292664
# Validation score: 0.392523
# Iteration 17, loss = 1.39929318
# Validation score: 0.386293
# Iteration 18, loss = 1.39688961
# Validation score: 0.373832
# Iteration 19, loss = 1.39486419
# Validation score: 0.373832
# Iteration 20, loss = 1.39103684
# Validation score: 0.376947
# Iteration 21, loss = 1.38852378
# Validation score: 0.386293
# Iteration 22, loss = 1.38769043
# Validation score: 0.380062
# Iteration 23, loss = 1.38426414
# Validation score: 0.373832
# Iteration 24, loss = 1.38162977
# Validation score: 0.370717
# Iteration 25, loss = 1.38111163
# Validation score: 0.367601
# Iteration 26, loss = 1.37777286
# Validation score: 0.367601
# Iteration 27, loss = 1.37622107
# Validation score: 0.367601
# Iteration 28, loss = 1.37389486
# Validation score: 0.370717
# Iteration 29, loss = 1.37296514
# Validation score: 0.367601
# Iteration 30, loss = 1.37051048
# Validation score: 0.370717
# Iteration 31, loss = 1.36932224
# Validation score: 0.373832
# Iteration 32, loss = 1.36748563
# Validation score: 0.376947
# Iteration 33, loss = 1.36677056
# Validation score: 0.376947
# Iteration 34, loss = 1.36489555
# Validation score: 0.348910
# Iteration 35, loss = 1.36349741
# Validation score: 0.361371
# Iteration 36, loss = 1.36215020
# Validation score: 0.364486
# Iteration 37, loss = 1.36015624
# Validation score: 0.361371
# Iteration 38, loss = 1.35930475
# Validation score: 0.370717
# Iteration 39, loss = 1.35892648
# Validation score: 0.370717
# Iteration 40, loss = 1.35664866
# Validation score: 0.376947
# Iteration 41, loss = 1.35703587
# Validation score: 0.373832
# Iteration 42, loss = 1.35529203
# Validation score: 0.355140
# Iteration 43, loss = 1.35416449
# Validation score: 0.376947
# Iteration 44, loss = 1.35273566
# Validation score: 0.376947
# Iteration 45, loss = 1.35275528
# Validation score: 0.370717
# Iteration 46, loss = 1.35070738
# Validation score: 0.383178
# Iteration 47, loss = 1.35050368
# Validation score: 0.370717
# Iteration 48, loss = 1.34979366
# Validation score: 0.373832
# Iteration 49, loss = 1.34873231
# Validation score: 0.380062
# Iteration 50, loss = 1.34854830
# Validation score: 0.380062
# Iteration 51, loss = 1.34712832
# Validation score: 0.361371
# Iteration 52, loss = 1.34551162
# Validation score: 0.376947
# Iteration 53, loss = 1.34523856
# Validation score: 0.370717
# Iteration 54, loss = 1.34569803
# Validation score: 0.373832
# Iteration 55, loss = 1.34411255
# Validation score: 0.376947
# Iteration 56, loss = 1.34398337
# Validation score: 0.370717
# Iteration 57, loss = 1.34234471
# Validation score: 0.352025
# Iteration 58, loss = 1.34151138
# Validation score: 0.370717
# Iteration 59, loss = 1.34041973
# Validation score: 0.364486
# Iteration 60, loss = 1.34012563
# Validation score: 0.358255
# Iteration 61, loss = 1.34000621
# Validation score: 0.364486
# Iteration 62, loss = 1.33907474
# Validation score: 0.370717
# Iteration 63, loss = 1.33884986
# Validation score: 0.348910
# Iteration 64, loss = 1.33817703
# Validation score: 0.358255
# Iteration 65, loss = 1.33625623
# Validation score: 0.370717
# Iteration 66, loss = 1.33596418
# Validation score: 0.355140
# Iteration 67, loss = 1.33487923
# Validation score: 0.355140
# Iteration 68, loss = 1.33367851
# Validation score: 0.361371
# Iteration 69, loss = 1.33546461
# Validation score: 0.364486
# Iteration 70, loss = 1.33419569
# Validation score: 0.348910
# Iteration 71, loss = 1.33272704
# Validation score: 0.355140
# Iteration 72, loss = 1.33311338
# Validation score: 0.345794
# Iteration 73, loss = 1.33186734
# Validation score: 0.345794
# Iteration 74, loss = 1.33148875
# Validation score: 0.355140
# Iteration 75, loss = 1.33140867
# Validation score: 0.342679
# Iteration 76, loss = 1.33030896
# Validation score: 0.342679
# Iteration 77, loss = 1.33000063
# Validation score: 0.364486
# Iteration 78, loss = 1.32876242
# Validation score: 0.367601
# Iteration 79, loss = 1.32870764
# Validation score: 0.355140
# Iteration 80, loss = 1.32871385
# Validation score: 0.355140
# Iteration 81, loss = 1.32798513
# Validation score: 0.361371
# Iteration 82, loss = 1.32712913
# Validation score: 0.358255
# Iteration 83, loss = 1.32692426
# Validation score: 0.342679
# Iteration 84, loss = 1.32631151
# Validation score: 0.361371
# Iteration 85, loss = 1.32552959
# Validation score: 0.361371
# Iteration 86, loss = 1.32538292
# Validation score: 0.370717
# Iteration 87, loss = 1.32553136
# Validation score: 0.352025
# Iteration 88, loss = 1.32460613
# Validation score: 0.355140
# Iteration 89, loss = 1.32429435
# Validation score: 0.345794
# Iteration 90, loss = 1.32382043
# Validation score: 0.358255
# Iteration 91, loss = 1.32229835
# Validation score: 0.380062
# Iteration 92, loss = 1.32235444
# Validation score: 0.361371
# Validation score did not improve more than tol=0.000100 for 75 consecutive epochs. Stopping.
# Iteration 1, loss = 2.13842859
# Validation score: 0.327103
# Iteration 2, loss = 1.55269383
# Validation score: 0.476636
# Iteration 3, loss = 1.40067473
# Validation score: 0.489097
# Iteration 4, loss = 1.34938213
# Validation score: 0.492212
# Iteration 5, loss = 1.32075889
# Validation score: 0.498442
# Iteration 6, loss = 1.30115259
# Validation score: 0.498442
# Iteration 7, loss = 1.28596980
# Validation score: 0.504673
# Iteration 8, loss = 1.27461704
# Validation score: 0.507788
# Iteration 9, loss = 1.26385177
# Validation score: 0.504673
# Iteration 10, loss = 1.25462936
# Validation score: 0.498442
# Iteration 11, loss = 1.24712264
# Validation score: 0.492212
# Iteration 12, loss = 1.24060080
# Validation score: 0.495327
# Iteration 13, loss = 1.23393852
# Validation score: 0.501558
# Iteration 14, loss = 1.22779291
# Validation score: 0.504673
# Iteration 15, loss = 1.22143680
# Validation score: 0.492212
# Iteration 16, loss = 1.21718204
# Validation score: 0.504673
# Iteration 17, loss = 1.21279281
# Validation score: 0.501558
# Iteration 18, loss = 1.20808641
# Validation score: 0.514019
# Iteration 19, loss = 1.20404359
# Validation score: 0.517134
# Iteration 20, loss = 1.20153182
# Validation score: 0.510903
# Iteration 21, loss = 1.19731065
# Validation score: 0.514019
# Iteration 22, loss = 1.19452320
# Validation score: 0.510903
# Iteration 23, loss = 1.19184820
# Validation score: 0.514019
# Iteration 24, loss = 1.18923753
# Validation score: 0.520249
# Iteration 25, loss = 1.18626574
# Validation score: 0.514019
# Iteration 26, loss = 1.18299643
# Validation score: 0.520249
# Iteration 27, loss = 1.18130925
# Validation score: 0.517134
# Iteration 28, loss = 1.17954352
# Validation score: 0.510903
# Iteration 29, loss = 1.17647442
# Validation score: 0.517134
# Iteration 30, loss = 1.17478389
# Validation score: 0.514019
# Iteration 31, loss = 1.17348393
# Validation score: 0.517134
# Iteration 32, loss = 1.17153803
# Validation score: 0.517134
# Iteration 33, loss = 1.16892846
# Validation score: 0.514019
# Iteration 34, loss = 1.16758734
# Validation score: 0.514019
# Iteration 35, loss = 1.16463642
# Validation score: 0.504673
# Iteration 36, loss = 1.16345884
# Validation score: 0.510903
# Iteration 37, loss = 1.16252644
# Validation score: 0.504673
# Iteration 38, loss = 1.16038143
# Validation score: 0.510903
# Iteration 39, loss = 1.15917578
# Validation score: 0.501558
# Iteration 40, loss = 1.15761552
# Validation score: 0.504673
# Iteration 41, loss = 1.15595401
# Validation score: 0.504673
# Iteration 42, loss = 1.15427957
# Validation score: 0.510903
# Iteration 43, loss = 1.15460289
# Validation score: 0.514019
# Iteration 44, loss = 1.15297810
# Validation score: 0.498442
# Iteration 45, loss = 1.15126272
# Validation score: 0.504673
# Iteration 46, loss = 1.14927841
# Validation score: 0.507788
# Iteration 47, loss = 1.14928009
# Validation score: 0.514019
# Iteration 48, loss = 1.14769642
# Validation score: 0.504673
# Iteration 49, loss = 1.14715177
# Validation score: 0.510903
# Iteration 50, loss = 1.14556916
# Validation score: 0.514019
# Iteration 51, loss = 1.14584851
# Validation score: 0.498442
# Iteration 52, loss = 1.14410077
# Validation score: 0.498442
# Iteration 53, loss = 1.14343009
# Validation score: 0.507788
# Iteration 54, loss = 1.14186040
# Validation score: 0.510903
# Iteration 55, loss = 1.14182029
# Validation score: 0.507788
# Iteration 56, loss = 1.14067521
# Validation score: 0.514019
# Iteration 57, loss = 1.14104685
# Validation score: 0.507788
# Iteration 58, loss = 1.14007408
# Validation score: 0.510903
# Iteration 59, loss = 1.13779222
# Validation score: 0.504673
# Iteration 60, loss = 1.13861800
# Validation score: 0.517134
# Iteration 61, loss = 1.13754364
# Validation score: 0.514019
# Iteration 62, loss = 1.13739749
# Validation score: 0.520249
# Iteration 63, loss = 1.13612585
# Validation score: 0.501558
# Iteration 64, loss = 1.13531573
# Validation score: 0.514019
# Iteration 65, loss = 1.13470392
# Validation score: 0.517134
# Iteration 66, loss = 1.13387028
# Validation score: 0.517134
# Iteration 67, loss = 1.13413008
# Validation score: 0.510903
# Iteration 68, loss = 1.13366645
# Validation score: 0.510903
# Iteration 69, loss = 1.13220263
# Validation score: 0.495327
# Iteration 70, loss = 1.13304399
# Validation score: 0.517134
# Iteration 71, loss = 1.13155679
# Validation score: 0.514019
# Iteration 72, loss = 1.13084416
# Validation score: 0.517134
# Iteration 73, loss = 1.13055880
# Validation score: 0.507788
# Iteration 74, loss = 1.12980538
# Validation score: 0.514019
# Iteration 75, loss = 1.13091522
# Validation score: 0.507788
# Iteration 76, loss = 1.12850855
# Validation score: 0.517134
# Iteration 77, loss = 1.12935929
# Validation score: 0.507788
# Iteration 78, loss = 1.12869747
# Validation score: 0.507788
# Iteration 79, loss = 1.12802332
# Validation score: 0.510903
# Iteration 80, loss = 1.12729263
# Validation score: 0.507788
# Iteration 81, loss = 1.12745191
# Validation score: 0.504673
# Iteration 82, loss = 1.12624862
# Validation score: 0.510903
# Iteration 83, loss = 1.12507163
# Validation score: 0.517134
# Iteration 84, loss = 1.12514235
# Validation score: 0.514019
# Iteration 85, loss = 1.12565055
# Validation score: 0.510903
# Iteration 86, loss = 1.12480321
# Validation score: 0.507788
# Iteration 87, loss = 1.12488524
# Validation score: 0.514019
# Iteration 88, loss = 1.12385520
# Validation score: 0.510903
# Iteration 89, loss = 1.12480874
# Validation score: 0.517134
# Iteration 90, loss = 1.12313197
# Validation score: 0.514019
# Iteration 91, loss = 1.12335578
# Validation score: 0.514019
# Iteration 92, loss = 1.12199305
# Validation score: 0.514019
# Iteration 93, loss = 1.12143180
# Validation score: 0.520249
# Iteration 94, loss = 1.12143703
# Validation score: 0.517134
# Iteration 95, loss = 1.12107532
# Validation score: 0.526480
# Iteration 96, loss = 1.12037665
# Validation score: 0.523364
# Iteration 97, loss = 1.12095634
# Validation score: 0.523364
# Iteration 98, loss = 1.11975950
# Validation score: 0.514019
# Iteration 99, loss = 1.11964143
# Validation score: 0.517134
# Iteration 100, loss = 1.11978333
# Validation score: 0.517134
# Iteration 101, loss = 1.11941722
# Validation score: 0.507788
# Iteration 102, loss = 1.11879853
# Validation score: 0.520249
# Iteration 103, loss = 1.11779513
# Validation score: 0.510903
# Iteration 104, loss = 1.11777960
# Validation score: 0.517134
# Iteration 105, loss = 1.11735586
# Validation score: 0.523364
# Iteration 106, loss = 1.11698315
# Validation score: 0.517134
# Iteration 107, loss = 1.11706121
# Validation score: 0.514019
# Iteration 108, loss = 1.11752226
# Validation score: 0.520249
# Iteration 109, loss = 1.11574482
# Validation score: 0.517134
# Iteration 110, loss = 1.11592114
# Validation score: 0.517134
# Iteration 111, loss = 1.11551964
# Validation score: 0.510903
# Iteration 112, loss = 1.11455781
# Validation score: 0.507788
# Iteration 113, loss = 1.11619494
# Validation score: 0.517134
# Iteration 114, loss = 1.11387493
# Validation score: 0.520249
# Iteration 115, loss = 1.11580224
# Validation score: 0.523364
# Iteration 116, loss = 1.11371190
# Validation score: 0.517134
# Iteration 117, loss = 1.11395956
# Validation score: 0.514019
# Iteration 118, loss = 1.11321576
# Validation score: 0.517134
# Iteration 119, loss = 1.11364114
# Validation score: 0.523364
# Iteration 120, loss = 1.11363143
# Validation score: 0.517134
# Iteration 121, loss = 1.11246683
# Validation score: 0.517134
# Iteration 122, loss = 1.11328577
# Validation score: 0.517134
# Iteration 123, loss = 1.11215538
# Validation score: 0.517134
# Iteration 124, loss = 1.11193012
# Validation score: 0.526480
# Iteration 125, loss = 1.11157626
# Validation score: 0.517134
# Iteration 126, loss = 1.11115695
# Validation score: 0.517134
# Iteration 127, loss = 1.11009642
# Validation score: 0.514019
# Iteration 128, loss = 1.10964983
# Validation score: 0.520249
# Iteration 129, loss = 1.10888605
# Validation score: 0.520249
# Iteration 130, loss = 1.10984058
# Validation score: 0.529595
# Iteration 131, loss = 1.10923164
# Validation score: 0.523364
# Iteration 132, loss = 1.10815754
# Validation score: 0.523364
# Iteration 133, loss = 1.10848174
# Validation score: 0.529595
# Iteration 134, loss = 1.10865430
# Validation score: 0.523364
# Iteration 135, loss = 1.10695745
# Validation score: 0.510903
# Iteration 136, loss = 1.10701229
# Validation score: 0.514019
# Iteration 137, loss = 1.10707376
# Validation score: 0.520249
# Iteration 138, loss = 1.10661864
# Validation score: 0.523364
# Iteration 139, loss = 1.10628211
# Validation score: 0.514019
# Iteration 140, loss = 1.10582070
# Validation score: 0.523364
# Iteration 141, loss = 1.10496573
# Validation score: 0.517134
# Iteration 142, loss = 1.10489035
# Validation score: 0.526480
# Iteration 143, loss = 1.10451527
# Validation score: 0.520249
# Iteration 144, loss = 1.10460359
# Validation score: 0.520249
# Iteration 145, loss = 1.10447781
# Validation score: 0.523364
# Iteration 146, loss = 1.10388783
# Validation score: 0.517134
# Iteration 147, loss = 1.10357831
# Validation score: 0.517134
# Iteration 148, loss = 1.10236218
# Validation score: 0.514019
# Iteration 149, loss = 1.10182781
# Validation score: 0.510903
# Iteration 150, loss = 1.10286898
# Validation score: 0.520249
# Iteration 151, loss = 1.10229204
# Validation score: 0.507788
# Iteration 152, loss = 1.10128496
# Validation score: 0.514019
# Iteration 153, loss = 1.10198282
# Validation score: 0.514019
# Iteration 154, loss = 1.10008077
# Validation score: 0.510903
# Iteration 155, loss = 1.10066407
# Validation score: 0.510903
# Iteration 156, loss = 1.09976081
# Validation score: 0.526480
# Iteration 157, loss = 1.10063381
# Validation score: 0.517134
# Iteration 158, loss = 1.09922103
# Validation score: 0.514019
# Iteration 159, loss = 1.09879529
# Validation score: 0.507788
# Iteration 160, loss = 1.09891570
# Validation score: 0.510903
# Iteration 161, loss = 1.09903070
# Validation score: 0.510903
# Iteration 162, loss = 1.09851927
# Validation score: 0.507788
# Iteration 163, loss = 1.09833938
# Validation score: 0.507788
# Iteration 164, loss = 1.09755087
# Validation score: 0.510903
# Iteration 165, loss = 1.09678245
# Validation score: 0.507788
# Iteration 166, loss = 1.09786483
# Validation score: 0.517134
# Iteration 167, loss = 1.09708148
# Validation score: 0.510903
# Iteration 168, loss = 1.09736049
# Validation score: 0.510903
# Iteration 169, loss = 1.09737769
# Validation score: 0.507788
# Iteration 170, loss = 1.09680146
# Validation score: 0.507788
# Iteration 171, loss = 1.09553136
# Validation score: 0.501558
# Iteration 172, loss = 1.09652270
# Validation score: 0.504673
# Iteration 173, loss = 1.09523381
# Validation score: 0.507788
# Iteration 174, loss = 1.09649785
# Validation score: 0.514019
# Iteration 175, loss = 1.09586085
# Validation score: 0.514019
# Iteration 176, loss = 1.09473157
# Validation score: 0.507788
# Iteration 177, loss = 1.09499343
# Validation score: 0.514019
# Iteration 178, loss = 1.09467971
# Validation score: 0.507788
# Iteration 179, loss = 1.09448349
# Validation score: 0.514019
# Iteration 180, loss = 1.09472115
# Validation score: 0.504673
# Iteration 181, loss = 1.09375198
# Validation score: 0.510903
# Iteration 182, loss = 1.09412015
# Validation score: 0.507788
# Iteration 183, loss = 1.09370836
# Validation score: 0.510903
# Iteration 184, loss = 1.09359228
# Validation score: 0.510903
# Iteration 185, loss = 1.09257650
# Validation score: 0.504673
# Iteration 186, loss = 1.09247097
# Validation score: 0.507788
# Iteration 187, loss = 1.09403739
# Validation score: 0.507788
# Iteration 188, loss = 1.09234037
# Validation score: 0.507788
# Iteration 189, loss = 1.09236672
# Validation score: 0.507788
# Iteration 190, loss = 1.09312673
# Validation score: 0.498442
# Iteration 191, loss = 1.09184800
# Validation score: 0.510903
# Iteration 192, loss = 1.09241738
# Validation score: 0.504673
# Iteration 193, loss = 1.09159267
# Validation score: 0.510903
# Iteration 194, loss = 1.09135961
# Validation score: 0.504673
# Iteration 195, loss = 1.09072611
# Validation score: 0.504673
# Iteration 196, loss = 1.09188616
# Validation score: 0.504673
# Iteration 197, loss = 1.09114969
# Validation score: 0.504673
# Iteration 198, loss = 1.09078974
# Validation score: 0.504673
# Iteration 199, loss = 1.09091747
# Validation score: 0.507788
# Iteration 200, loss = 1.09102410
# Validation score: 0.495327
# Iteration 201, loss = 1.08995000
# Validation score: 0.498442
# Iteration 202, loss = 1.09018876
# Validation score: 0.501558
# Iteration 203, loss = 1.08890303
# Validation score: 0.498442
# Iteration 204, loss = 1.08949648
# Validation score: 0.498442
# Iteration 205, loss = 1.08952990
# Validation score: 0.495327
# Iteration 206, loss = 1.08872094
# Validation score: 0.507788
# Validation score did not improve more than tol=0.000100 for 75 consecutive epochs. Stopping.
# Iteration 1, loss = 1.45330568
# Validation score: 0.694704
# Iteration 2, loss = 1.06369631
# Validation score: 0.722741
# Iteration 3, loss = 0.96969655
# Validation score: 0.722741
# Iteration 4, loss = 0.93353974
# Validation score: 0.722741
# Iteration 5, loss = 0.91553159
# Validation score: 0.722741
# Iteration 6, loss = 0.90127966
# Validation score: 0.722741
# Iteration 7, loss = 0.89271492
# Validation score: 0.722741
# Iteration 8, loss = 0.88619660
# Validation score: 0.722741
# Iteration 9, loss = 0.88001412
# Validation score: 0.722741
# Iteration 10, loss = 0.87478124
# Validation score: 0.722741
# Iteration 11, loss = 0.87099779
# Validation score: 0.722741
# Iteration 12, loss = 0.86685560
# Validation score: 0.722741
# Iteration 13, loss = 0.86383140
# Validation score: 0.722741
# Iteration 14, loss = 0.86082068
# Validation score: 0.722741
# Iteration 15, loss = 0.85940063
# Validation score: 0.722741
# Iteration 16, loss = 0.85641006
# Validation score: 0.722741
# Iteration 17, loss = 0.85518560
# Validation score: 0.722741
# Iteration 18, loss = 0.85260047
# Validation score: 0.722741
# Iteration 19, loss = 0.85021905
# Validation score: 0.722741
# Iteration 20, loss = 0.84909573
# Validation score: 0.722741
# Iteration 21, loss = 0.84699246
# Validation score: 0.722741
# Iteration 22, loss = 0.84546223
# Validation score: 0.722741
# Iteration 23, loss = 0.84476729
# Validation score: 0.722741
# Iteration 24, loss = 0.84263312
# Validation score: 0.722741
# Iteration 25, loss = 0.84204993
# Validation score: 0.722741
# Iteration 26, loss = 0.84037840
# Validation score: 0.722741
# Iteration 27, loss = 0.83930354
# Validation score: 0.722741
# Iteration 28, loss = 0.83877480
# Validation score: 0.722741
# Iteration 29, loss = 0.83680280
# Validation score: 0.722741
# Iteration 30, loss = 0.83636797
# Validation score: 0.722741
# Iteration 31, loss = 0.83564056
# Validation score: 0.722741
# Iteration 32, loss = 0.83432958
# Validation score: 0.722741
# Iteration 33, loss = 0.83349952
# Validation score: 0.722741
# Iteration 34, loss = 0.83164546
# Validation score: 0.722741
# Iteration 35, loss = 0.83133460
# Validation score: 0.722741
# Iteration 36, loss = 0.82929985
# Validation score: 0.722741
# Iteration 37, loss = 0.82935014
# Validation score: 0.722741
# Iteration 38, loss = 0.82811461
# Validation score: 0.722741
# Iteration 39, loss = 0.82640110
# Validation score: 0.722741
# Iteration 40, loss = 0.82615518
# Validation score: 0.722741
# Iteration 41, loss = 0.82432428
# Validation score: 0.722741
# Iteration 42, loss = 0.82359176
# Validation score: 0.722741
# Iteration 43, loss = 0.82263214
# Validation score: 0.722741
# Iteration 44, loss = 0.82126796
# Validation score: 0.722741
# Iteration 45, loss = 0.82037760
# Validation score: 0.722741
# Iteration 46, loss = 0.81935586
# Validation score: 0.722741
# Iteration 47, loss = 0.81901908
# Validation score: 0.722741
# Iteration 48, loss = 0.81845480
# Validation score: 0.722741
# Iteration 49, loss = 0.81666992
# Validation score: 0.722741
# Iteration 50, loss = 0.81715220
# Validation score: 0.722741
# Iteration 51, loss = 0.81580817
# Validation score: 0.722741
# Iteration 52, loss = 0.81486990
# Validation score: 0.722741
# Iteration 53, loss = 0.81371462
# Validation score: 0.722741
# Iteration 54, loss = 0.81307720
# Validation score: 0.722741
# Iteration 55, loss = 0.81300713
# Validation score: 0.722741
# Iteration 56, loss = 0.81152055
# Validation score: 0.722741
# Iteration 57, loss = 0.81121233
# Validation score: 0.722741
# Iteration 58, loss = 0.80970679
# Validation score: 0.722741
# Iteration 59, loss = 0.80996866
# Validation score: 0.722741
# Iteration 60, loss = 0.80900423
# Validation score: 0.722741
# Iteration 61, loss = 0.80861363
# Validation score: 0.722741
# Iteration 62, loss = 0.80757564
# Validation score: 0.722741
# Iteration 63, loss = 0.80676483
# Validation score: 0.722741
# Iteration 64, loss = 0.80587395
# Validation score: 0.722741
# Iteration 65, loss = 0.80519780
# Validation score: 0.722741
# Iteration 66, loss = 0.80465499
# Validation score: 0.722741
# Iteration 67, loss = 0.80467712
# Validation score: 0.722741
# Iteration 68, loss = 0.80308000
# Validation score: 0.722741
# Iteration 69, loss = 0.80216134
# Validation score: 0.722741
# Iteration 70, loss = 0.80200804
# Validation score: 0.722741
# Iteration 71, loss = 0.80141716
# Validation score: 0.722741
# Iteration 72, loss = 0.80097899
# Validation score: 0.722741
# Iteration 73, loss = 0.80041601
# Validation score: 0.722741
# Iteration 74, loss = 0.79998451
# Validation score: 0.722741
# Iteration 75, loss = 0.79953319
# Validation score: 0.722741
# Iteration 76, loss = 0.79825968
# Validation score: 0.722741
# Iteration 77, loss = 0.79807548
# Validation score: 0.722741
# Iteration 78, loss = 0.79677505
# Validation score: 0.722741
# Validation score did not improve more than tol=0.000100 for 75 consecutive epochs. Stopping.
# Iteration 1, loss = 2.04086662
# Validation score: 0.333333
# Iteration 2, loss = 1.73498721
# Validation score: 0.398754
# Iteration 3, loss = 1.62297573
# Validation score: 0.411215
# Iteration 4, loss = 1.56939332
# Validation score: 0.417445
# Iteration 5, loss = 1.53873232
# Validation score: 0.423676
# Iteration 6, loss = 1.51962844
# Validation score: 0.414330
# Iteration 7, loss = 1.50636195
# Validation score: 0.414330
# Iteration 8, loss = 1.49557568
# Validation score: 0.414330
# Iteration 9, loss = 1.48719747
# Validation score: 0.417445
# Iteration 10, loss = 1.48107096
# Validation score: 0.420561
# Iteration 11, loss = 1.47520142
# Validation score: 0.417445
# Iteration 12, loss = 1.47139266
# Validation score: 0.423676
# Iteration 13, loss = 1.46593688
# Validation score: 0.423676
# Iteration 14, loss = 1.46215868
# Validation score: 0.423676
# Iteration 15, loss = 1.45976696
# Validation score: 0.426791
# Iteration 16, loss = 1.45733435
# Validation score: 0.429907
# Iteration 17, loss = 1.45278771
# Validation score: 0.429907
# Iteration 18, loss = 1.45074189
# Validation score: 0.429907
# Iteration 19, loss = 1.44887504
# Validation score: 0.433022
# Iteration 20, loss = 1.44536847
# Validation score: 0.433022
# Iteration 21, loss = 1.44323054
# Validation score: 0.436137
# Iteration 22, loss = 1.44133734
# Validation score: 0.436137
# Iteration 23, loss = 1.43920767
# Validation score: 0.429907
# Iteration 24, loss = 1.43718988
# Validation score: 0.423676
# Iteration 25, loss = 1.43538993
# Validation score: 0.420561
# Iteration 26, loss = 1.43346944
# Validation score: 0.429907
# Iteration 27, loss = 1.43207101
# Validation score: 0.436137
# Iteration 28, loss = 1.42965693
# Validation score: 0.429907
# Iteration 29, loss = 1.42854729
# Validation score: 0.436137
# Iteration 30, loss = 1.42561380
# Validation score: 0.436137
# Iteration 31, loss = 1.42470153
# Validation score: 0.445483
# Iteration 32, loss = 1.42323636
# Validation score: 0.433022
# Iteration 33, loss = 1.42220368
# Validation score: 0.436137
# Iteration 34, loss = 1.41971367
# Validation score: 0.439252
# Iteration 35, loss = 1.41841972
# Validation score: 0.445483
# Iteration 36, loss = 1.41660819
# Validation score: 0.439252
# Iteration 37, loss = 1.41578937
# Validation score: 0.445483
# Iteration 38, loss = 1.41337094
# Validation score: 0.445483
# Iteration 39, loss = 1.41283588
# Validation score: 0.454829
# Iteration 40, loss = 1.41134728
# Validation score: 0.445483
# Iteration 41, loss = 1.40970899
# Validation score: 0.445483
# Iteration 42, loss = 1.40858237
# Validation score: 0.454829
# Iteration 43, loss = 1.40719699
# Validation score: 0.464174
# Iteration 44, loss = 1.40570169
# Validation score: 0.457944
# Iteration 45, loss = 1.40422141
# Validation score: 0.454829
# Iteration 46, loss = 1.40240901
# Validation score: 0.454829
# Iteration 47, loss = 1.40262229
# Validation score: 0.448598
# Iteration 48, loss = 1.40091531
# Validation score: 0.454829
# Iteration 49, loss = 1.39929959
# Validation score: 0.467290
# Iteration 50, loss = 1.39906118
# Validation score: 0.448598
# Iteration 51, loss = 1.39721467
# Validation score: 0.464174
# Iteration 52, loss = 1.39682227
# Validation score: 0.457944
# Iteration 53, loss = 1.39564018
# Validation score: 0.467290
# Iteration 54, loss = 1.39558542
# Validation score: 0.464174
# Iteration 55, loss = 1.39299984
# Validation score: 0.451713
# Iteration 56, loss = 1.39340774
# Validation score: 0.467290
# Iteration 57, loss = 1.39222331
# Validation score: 0.454829
# Iteration 58, loss = 1.39115237
# Validation score: 0.464174
# Iteration 59, loss = 1.38951200
# Validation score: 0.464174
# Iteration 60, loss = 1.38961525
# Validation score: 0.457944
# Iteration 61, loss = 1.38871264
# Validation score: 0.454829
# Iteration 62, loss = 1.38886620
# Validation score: 0.454829
# Iteration 63, loss = 1.38664198
# Validation score: 0.457944
# Iteration 64, loss = 1.38529624
# Validation score: 0.454829
# Iteration 65, loss = 1.38445842
# Validation score: 0.451713
# Iteration 66, loss = 1.38500693
# Validation score: 0.454829
# Iteration 67, loss = 1.38351278
# Validation score: 0.461059
# Iteration 68, loss = 1.38329169
# Validation score: 0.451713
# Iteration 69, loss = 1.38175398
# Validation score: 0.454829
# Iteration 70, loss = 1.38077925
# Validation score: 0.457944
# Iteration 71, loss = 1.38007762
# Validation score: 0.464174
# Iteration 72, loss = 1.37978683
# Validation score: 0.473520
# Iteration 73, loss = 1.37814151
# Validation score: 0.451713
# Iteration 74, loss = 1.37829171
# Validation score: 0.454829
# Iteration 75, loss = 1.37841772
# Validation score: 0.464174
# Iteration 76, loss = 1.37734825
# Validation score: 0.461059
# Iteration 77, loss = 1.37628364
# Validation score: 0.464174
# Iteration 78, loss = 1.37449544
# Validation score: 0.464174
# Iteration 79, loss = 1.37443384
# Validation score: 0.461059
# Iteration 80, loss = 1.37394801
# Validation score: 0.461059
# Iteration 81, loss = 1.37339534
# Validation score: 0.464174
# Iteration 82, loss = 1.37214184
# Validation score: 0.461059
# Iteration 83, loss = 1.37176284
# Validation score: 0.464174
# Iteration 84, loss = 1.37303536
# Validation score: 0.454829
# Iteration 85, loss = 1.37057575
# Validation score: 0.457944
# Iteration 86, loss = 1.36952900
# Validation score: 0.448598
# Iteration 87, loss = 1.37043880
# Validation score: 0.464174
# Iteration 88, loss = 1.36919146
# Validation score: 0.464174
# Iteration 89, loss = 1.36785954
# Validation score: 0.464174
# Iteration 90, loss = 1.36716185
# Validation score: 0.454829
# Iteration 91, loss = 1.36692685
# Validation score: 0.457944
# Iteration 92, loss = 1.36724979
# Validation score: 0.461059
# Iteration 93, loss = 1.36573084
# Validation score: 0.451713
# Iteration 94, loss = 1.36576054
# Validation score: 0.448598
# Iteration 95, loss = 1.36603417
# Validation score: 0.457944
# Iteration 96, loss = 1.36451359
# Validation score: 0.451713
# Iteration 97, loss = 1.36465812
# Validation score: 0.457944
# Iteration 98, loss = 1.36339503
# Validation score: 0.461059
# Iteration 99, loss = 1.36326125
# Validation score: 0.451713
# Iteration 100, loss = 1.36333141
# Validation score: 0.457944
# Iteration 101, loss = 1.36232274
# Validation score: 0.457944
# Iteration 102, loss = 1.36228536
# Validation score: 0.454829
# Iteration 103, loss = 1.36250314
# Validation score: 0.454829
# Iteration 104, loss = 1.36199457
# Validation score: 0.451713
# Iteration 105, loss = 1.36121485
# Validation score: 0.454829
# Iteration 106, loss = 1.35997110
# Validation score: 0.454829
# Iteration 107, loss = 1.36070284
# Validation score: 0.457944
# Iteration 108, loss = 1.35929355
# Validation score: 0.448598
# Iteration 109, loss = 1.36001899
# Validation score: 0.454829
# Iteration 110, loss = 1.35929161
# Validation score: 0.454829
# Iteration 111, loss = 1.35876522
# Validation score: 0.454829
# Iteration 112, loss = 1.35955154
# Validation score: 0.451713
# Iteration 113, loss = 1.35841849
# Validation score: 0.436137
# Iteration 114, loss = 1.35795692
# Validation score: 0.451713
# Iteration 115, loss = 1.35727406
# Validation score: 0.467290
# Iteration 116, loss = 1.35812001
# Validation score: 0.467290
# Iteration 117, loss = 1.35744731
# Validation score: 0.457944
# Iteration 118, loss = 1.35712471
# Validation score: 0.457944
# Iteration 119, loss = 1.35617835
# Validation score: 0.457944
# Iteration 120, loss = 1.35626510
# Validation score: 0.461059
# Iteration 121, loss = 1.35580685
# Validation score: 0.461059
# Iteration 122, loss = 1.35538442
# Validation score: 0.461059
# Iteration 123, loss = 1.35506533
# Validation score: 0.464174
# Iteration 124, loss = 1.35518870
# Validation score: 0.454829
# Iteration 125, loss = 1.35473064
# Validation score: 0.454829
# Iteration 126, loss = 1.35497355
# Validation score: 0.454829
# Iteration 127, loss = 1.35427085
# Validation score: 0.442368
# Iteration 128, loss = 1.35500749
# Validation score: 0.454829
# Iteration 129, loss = 1.35412917
# Validation score: 0.451713
# Iteration 130, loss = 1.35347116
# Validation score: 0.457944
# Iteration 131, loss = 1.35296465
# Validation score: 0.454829
# Iteration 132, loss = 1.35266305
# Validation score: 0.448598
# Iteration 133, loss = 1.35360809
# Validation score: 0.433022
# Iteration 134, loss = 1.35085962
# Validation score: 0.454829
# Iteration 135, loss = 1.35247590
# Validation score: 0.457944
# Iteration 136, loss = 1.35051646
# Validation score: 0.451713
# Iteration 137, loss = 1.35024042
# Validation score: 0.454829
# Iteration 138, loss = 1.35059177
# Validation score: 0.445483
# Iteration 139, loss = 1.34928976
# Validation score: 0.448598
# Iteration 140, loss = 1.35032448
# Validation score: 0.442368
# Iteration 141, loss = 1.34912901
# Validation score: 0.442368
# Iteration 142, loss = 1.35000519
# Validation score: 0.436137
# Iteration 143, loss = 1.34879827
# Validation score: 0.457944
# Iteration 144, loss = 1.34922666
# Validation score: 0.454829
# Iteration 145, loss = 1.34854066
# Validation score: 0.439252
# Iteration 146, loss = 1.34667259
# Validation score: 0.436137
# Iteration 147, loss = 1.34823444
# Validation score: 0.445483
# Iteration 148, loss = 1.34680729
# Validation score: 0.439252
# Validation score did not improve more than tol=0.000100 for 75 consecutive epochs. Stopping.
# Iteration 1, loss = 1.78002827
# Validation score: 0.345794
# Iteration 2, loss = 1.42679216
# Validation score: 0.398754
# Iteration 3, loss = 1.32035718
# Validation score: 0.417445
# Iteration 4, loss = 1.27814218
# Validation score: 0.423676
# Iteration 5, loss = 1.25645832
# Validation score: 0.417445
# Iteration 6, loss = 1.24316327
# Validation score: 0.408100
# Iteration 7, loss = 1.23378100
# Validation score: 0.414330
# Iteration 8, loss = 1.22703272
# Validation score: 0.423676
# Iteration 9, loss = 1.22183379
# Validation score: 0.426791
# Iteration 10, loss = 1.21794688
# Validation score: 0.420561
# Iteration 11, loss = 1.21421323
# Validation score: 0.414330
# Iteration 12, loss = 1.21071232
# Validation score: 0.423676
# Iteration 13, loss = 1.20823660
# Validation score: 0.414330
# Iteration 14, loss = 1.20607214
# Validation score: 0.426791
# Iteration 15, loss = 1.20285198
# Validation score: 0.433022
# Iteration 16, loss = 1.20189600
# Validation score: 0.436137
# Iteration 17, loss = 1.19931984
# Validation score: 0.426791
# Iteration 18, loss = 1.19677841
# Validation score: 0.420561
# Iteration 19, loss = 1.19465080
# Validation score: 0.420561
# Iteration 20, loss = 1.19385229
# Validation score: 0.433022
# Iteration 21, loss = 1.19182184
# Validation score: 0.414330
# Iteration 22, loss = 1.19001997
# Validation score: 0.417445
# Iteration 23, loss = 1.18865915
# Validation score: 0.429907
# Iteration 24, loss = 1.18706063
# Validation score: 0.423676
# Iteration 25, loss = 1.18508612
# Validation score: 0.423676
# Iteration 26, loss = 1.18374986
# Validation score: 0.436137
# Iteration 27, loss = 1.18226604
# Validation score: 0.414330
# Iteration 28, loss = 1.18080573
# Validation score: 0.429907
# Iteration 29, loss = 1.18028214
# Validation score: 0.429907
# Iteration 30, loss = 1.17780163
# Validation score: 0.408100
# Iteration 31, loss = 1.17719501
# Validation score: 0.411215
# Iteration 32, loss = 1.17529876
# Validation score: 0.414330
# Iteration 33, loss = 1.17420111
# Validation score: 0.420561
# Iteration 34, loss = 1.17311820
# Validation score: 0.420561
# Iteration 35, loss = 1.17180288
# Validation score: 0.404984
# Iteration 36, loss = 1.17125413
# Validation score: 0.423676
# Iteration 37, loss = 1.16900838
# Validation score: 0.433022
# Iteration 38, loss = 1.16767502
# Validation score: 0.414330
# Iteration 39, loss = 1.16670822
# Validation score: 0.420561
# Iteration 40, loss = 1.16574859
# Validation score: 0.420561
# Iteration 41, loss = 1.16428854
# Validation score: 0.414330
# Iteration 42, loss = 1.16302893
# Validation score: 0.423676
# Iteration 43, loss = 1.16165765
# Validation score: 0.426791
# Iteration 44, loss = 1.16128686
# Validation score: 0.411215
# Iteration 45, loss = 1.15955719
# Validation score: 0.411215
# Iteration 46, loss = 1.15874933
# Validation score: 0.417445
# Iteration 47, loss = 1.15757225
# Validation score: 0.408100
# Iteration 48, loss = 1.15647705
# Validation score: 0.417445
# Iteration 49, loss = 1.15619735
# Validation score: 0.426791
# Iteration 50, loss = 1.15562321
# Validation score: 0.414330
# Iteration 51, loss = 1.15436896
# Validation score: 0.417445
# Iteration 52, loss = 1.15340495
# Validation score: 0.426791
# Iteration 53, loss = 1.15191816
# Validation score: 0.426791
# Iteration 54, loss = 1.15260199
# Validation score: 0.426791
# Iteration 55, loss = 1.14992903
# Validation score: 0.429907
# Iteration 56, loss = 1.14946946
# Validation score: 0.417445
# Iteration 57, loss = 1.14964694
# Validation score: 0.414330
# Iteration 58, loss = 1.14773505
# Validation score: 0.420561
# Iteration 59, loss = 1.14812676
# Validation score: 0.433022
# Iteration 60, loss = 1.14798502
# Validation score: 0.420561
# Iteration 61, loss = 1.14572273
# Validation score: 0.436137
# Iteration 62, loss = 1.14626107
# Validation score: 0.414330
# Iteration 63, loss = 1.14574526
# Validation score: 0.423676
# Iteration 64, loss = 1.14515017
# Validation score: 0.411215
# Iteration 65, loss = 1.14331757
# Validation score: 0.423676
# Iteration 66, loss = 1.14246280
# Validation score: 0.429907
# Iteration 67, loss = 1.14305260
# Validation score: 0.423676
# Iteration 68, loss = 1.14264527
# Validation score: 0.404984
# Iteration 69, loss = 1.14077966
# Validation score: 0.404984
# Iteration 70, loss = 1.14036031
# Validation score: 0.426791
# Iteration 71, loss = 1.13970149
# Validation score: 0.414330
# Iteration 72, loss = 1.13856265
# Validation score: 0.420561
# Iteration 73, loss = 1.13854120
# Validation score: 0.411215
# Iteration 74, loss = 1.13707361
# Validation score: 0.420561
# Iteration 75, loss = 1.13624599
# Validation score: 0.426791
# Iteration 76, loss = 1.13529531
# Validation score: 0.411215
# Iteration 77, loss = 1.13425449
# Validation score: 0.414330
# Iteration 78, loss = 1.13440171
# Validation score: 0.414330
# Iteration 79, loss = 1.13319570
# Validation score: 0.414330
# Iteration 80, loss = 1.13324643
# Validation score: 0.429907
# Iteration 81, loss = 1.13214748
# Validation score: 0.429907
# Iteration 82, loss = 1.13061098
# Validation score: 0.420561
# Iteration 83, loss = 1.13051559
# Validation score: 0.420561
# Iteration 84, loss = 1.12977703
# Validation score: 0.417445
# Iteration 85, loss = 1.13004661
# Validation score: 0.417445
# Iteration 86, loss = 1.12805454
# Validation score: 0.436137
# Iteration 87, loss = 1.12837525
# Validation score: 0.420561
# Iteration 88, loss = 1.12655596
# Validation score: 0.420561
# Iteration 89, loss = 1.12605875
# Validation score: 0.439252
# Iteration 90, loss = 1.12628142
# Validation score: 0.439252
# Iteration 91, loss = 1.12512348
# Validation score: 0.411215
# Iteration 92, loss = 1.12422587
# Validation score: 0.436137
# Iteration 93, loss = 1.12354133
# Validation score: 0.426791
# Iteration 94, loss = 1.12262063
# Validation score: 0.420561
# Iteration 95, loss = 1.12276561
# Validation score: 0.429907
# Iteration 96, loss = 1.12252664
# Validation score: 0.426791
# Iteration 97, loss = 1.12090160
# Validation score: 0.420561
# Iteration 98, loss = 1.12100806
# Validation score: 0.414330
# Iteration 99, loss = 1.12094052
# Validation score: 0.420561
# Iteration 100, loss = 1.11979686
# Validation score: 0.414330
# Iteration 101, loss = 1.11988729
# Validation score: 0.401869
# Iteration 102, loss = 1.11777282
# Validation score: 0.426791
# Iteration 103, loss = 1.11795373
# Validation score: 0.420561
# Iteration 104, loss = 1.11781187
# Validation score: 0.414330
# Iteration 105, loss = 1.11673890
# Validation score: 0.420561
# Iteration 106, loss = 1.11680854
# Validation score: 0.414330
# Iteration 107, loss = 1.11666147
# Validation score: 0.414330
# Iteration 108, loss = 1.11634390
# Validation score: 0.408100
# Iteration 109, loss = 1.11380853
# Validation score: 0.423676
# Iteration 110, loss = 1.11412702
# Validation score: 0.404984
# Iteration 111, loss = 1.11344426
# Validation score: 0.429907
# Iteration 112, loss = 1.11383349
# Validation score: 0.417445
# Iteration 113, loss = 1.11211617
# Validation score: 0.436137
# Iteration 114, loss = 1.11291034
# Validation score: 0.411215
# Iteration 115, loss = 1.11246987
# Validation score: 0.411215
# Iteration 116, loss = 1.11253371
# Validation score: 0.420561
# Iteration 117, loss = 1.11168155
# Validation score: 0.404984
# Iteration 118, loss = 1.11025790
# Validation score: 0.408100
# Iteration 119, loss = 1.11014049
# Validation score: 0.417445
# Iteration 120, loss = 1.11059098
# Validation score: 0.414330
# Iteration 121, loss = 1.10989725
# Validation score: 0.423676
# Iteration 122, loss = 1.11029360
# Validation score: 0.417445
# Iteration 123, loss = 1.10841436
# Validation score: 0.417445
# Iteration 124, loss = 1.10762799
# Validation score: 0.398754
# Iteration 125, loss = 1.10860508
# Validation score: 0.426791
# Iteration 126, loss = 1.10826345
# Validation score: 0.404984
# Iteration 127, loss = 1.10792366
# Validation score: 0.411215
# Iteration 128, loss = 1.10816960
# Validation score: 0.423676
# Iteration 129, loss = 1.10808556
# Validation score: 0.411215
# Iteration 130, loss = 1.10740151
# Validation score: 0.417445
# Iteration 131, loss = 1.10573996
# Validation score: 0.417445
# Iteration 132, loss = 1.10617003
# Validation score: 0.408100
# Iteration 133, loss = 1.10565753
# Validation score: 0.420561
# Iteration 134, loss = 1.10605223
# Validation score: 0.408100
# Iteration 135, loss = 1.10522278
# Validation score: 0.420561
# Iteration 136, loss = 1.10667840
# Validation score: 0.408100
# Iteration 137, loss = 1.10441518
# Validation score: 0.426791
# Iteration 138, loss = 1.10517577
# Validation score: 0.411215
# Iteration 139, loss = 1.10444354
# Validation score: 0.417445
# Iteration 140, loss = 1.10493628
# Validation score: 0.404984
# Iteration 141, loss = 1.10553561
# Validation score: 0.401869
# Iteration 142, loss = 1.10387293
# Validation score: 0.411215
# Iteration 143, loss = 1.10343698
# Validation score: 0.423676
# Iteration 144, loss = 1.10389029
# Validation score: 0.417445
# Iteration 145, loss = 1.10439443
# Validation score: 0.420561
# Iteration 146, loss = 1.10251233
# Validation score: 0.408100
# Iteration 147, loss = 1.10318283
# Validation score: 0.398754
# Iteration 148, loss = 1.10227999
# Validation score: 0.408100
# Iteration 149, loss = 1.10180260
# Validation score: 0.404984
# Iteration 150, loss = 1.10178083
# Validation score: 0.401869
# Iteration 151, loss = 1.10132633
# Validation score: 0.420561
# Iteration 152, loss = 1.10069915
# Validation score: 0.414330
# Iteration 153, loss = 1.10008282
# Validation score: 0.414330
# Iteration 154, loss = 1.10064084
# Validation score: 0.417445
# Iteration 155, loss = 1.10026035
# Validation score: 0.420561
# Iteration 156, loss = 1.10024031
# Validation score: 0.420561
# Iteration 157, loss = 1.09982054
# Validation score: 0.408100
# Iteration 158, loss = 1.10129670
# Validation score: 0.411215
# Iteration 159, loss = 1.09854990
# Validation score: 0.404984
# Iteration 160, loss = 1.09917281
# Validation score: 0.401869
# Iteration 161, loss = 1.09847389
# Validation score: 0.417445
# Iteration 162, loss = 1.09785390
# Validation score: 0.389408
# Iteration 163, loss = 1.09950454
# Validation score: 0.408100
# Iteration 164, loss = 1.09792402
# Validation score: 0.408100
# Iteration 165, loss = 1.09864736
# Validation score: 0.408100
# Validation score did not improve more than tol=0.000100 for 75 consecutive epochs. Stopping.
# Iteration 1, loss = 2.11807417
# Validation score: 0.348910
# Iteration 2, loss = 1.51122765
# Validation score: 0.523364
# Iteration 3, loss = 1.35618845
# Validation score: 0.542056
# Iteration 4, loss = 1.30527909
# Validation score: 0.560748
# Iteration 5, loss = 1.27639298
# Validation score: 0.560748
# Iteration 6, loss = 1.25579564
# Validation score: 0.551402
# Iteration 7, loss = 1.24021268
# Validation score: 0.557632
# Iteration 8, loss = 1.22676069
# Validation score: 0.551402
# Iteration 9, loss = 1.21582525
# Validation score: 0.560748
# Iteration 10, loss = 1.20720706
# Validation score: 0.560748
# Iteration 11, loss = 1.19965390
# Validation score: 0.557632
# Iteration 12, loss = 1.19228838
# Validation score: 0.563863
# Iteration 13, loss = 1.18592605
# Validation score: 0.563863
# Iteration 14, loss = 1.18023747
# Validation score: 0.563863
# Iteration 15, loss = 1.17579143
# Validation score: 0.563863
# Iteration 16, loss = 1.17080755
# Validation score: 0.566978
# Iteration 17, loss = 1.16665972
# Validation score: 0.573209
# Iteration 18, loss = 1.16257806
# Validation score: 0.570093
# Iteration 19, loss = 1.15892577
# Validation score: 0.579439
# Iteration 20, loss = 1.15597947
# Validation score: 0.573209
# Iteration 21, loss = 1.15167917
# Validation score: 0.557632
# Iteration 22, loss = 1.15008061
# Validation score: 0.566978
# Iteration 23, loss = 1.14654648
# Validation score: 0.563863
# Iteration 24, loss = 1.14547742
# Validation score: 0.560748
# Iteration 25, loss = 1.14217748
# Validation score: 0.551402
# Iteration 26, loss = 1.13787948
# Validation score: 0.563863
# Iteration 27, loss = 1.13738386
# Validation score: 0.548287
# Iteration 28, loss = 1.13362764
# Validation score: 0.560748
# Iteration 29, loss = 1.13215159
# Validation score: 0.554517
# Iteration 30, loss = 1.13106679
# Validation score: 0.535826
# Iteration 31, loss = 1.12967427
# Validation score: 0.542056
# Iteration 32, loss = 1.12744210
# Validation score: 0.551402
# Iteration 33, loss = 1.12562121
# Validation score: 0.538941
# Iteration 34, loss = 1.12501660
# Validation score: 0.542056
# Iteration 35, loss = 1.12194831
# Validation score: 0.551402
# Iteration 36, loss = 1.12131796
# Validation score: 0.551402
# Iteration 37, loss = 1.12057736
# Validation score: 0.548287
# Iteration 38, loss = 1.11969631
# Validation score: 0.542056
# Iteration 39, loss = 1.11774580
# Validation score: 0.557632
# Iteration 40, loss = 1.11634171
# Validation score: 0.557632
# Iteration 41, loss = 1.11510429
# Validation score: 0.554517
# Iteration 42, loss = 1.11461894
# Validation score: 0.548287
# Iteration 43, loss = 1.11441918
# Validation score: 0.545171
# Iteration 44, loss = 1.11400871
# Validation score: 0.557632
# Iteration 45, loss = 1.11107304
# Validation score: 0.551402
# Iteration 46, loss = 1.11177573
# Validation score: 0.551402
# Iteration 47, loss = 1.10935119
# Validation score: 0.560748
# Iteration 48, loss = 1.10834199
# Validation score: 0.548287
# Iteration 49, loss = 1.10726106
# Validation score: 0.554517
# Iteration 50, loss = 1.10643508
# Validation score: 0.557632
# Iteration 51, loss = 1.10552594
# Validation score: 0.545171
# Iteration 52, loss = 1.10436983
# Validation score: 0.566978
# Iteration 53, loss = 1.10373693
# Validation score: 0.570093
# Iteration 54, loss = 1.10326406
# Validation score: 0.557632
# Iteration 55, loss = 1.10138523
# Validation score: 0.566978
# Iteration 56, loss = 1.10038605
# Validation score: 0.566978
# Iteration 57, loss = 1.10064606
# Validation score: 0.566978
# Iteration 58, loss = 1.09861806
# Validation score: 0.573209
# Iteration 59, loss = 1.09818279
# Validation score: 0.570093
# Iteration 60, loss = 1.09714911
# Validation score: 0.560748
# Iteration 61, loss = 1.09629969
# Validation score: 0.560748
# Iteration 62, loss = 1.09490899
# Validation score: 0.557632
# Iteration 63, loss = 1.09503568
# Validation score: 0.563863
# Iteration 64, loss = 1.09445109
# Validation score: 0.548287
# Iteration 65, loss = 1.09415006
# Validation score: 0.551402
# Iteration 66, loss = 1.09311503
# Validation score: 0.570093
# Iteration 67, loss = 1.09182561
# Validation score: 0.554517
# Iteration 68, loss = 1.09260134
# Validation score: 0.548287
# Iteration 69, loss = 1.09128297
# Validation score: 0.557632
# Iteration 70, loss = 1.09048772
# Validation score: 0.554517
# Iteration 71, loss = 1.08949154
# Validation score: 0.566978
# Iteration 72, loss = 1.08824583
# Validation score: 0.554517
# Iteration 73, loss = 1.08999642
# Validation score: 0.557632
# Iteration 74, loss = 1.08824133
# Validation score: 0.548287
# Iteration 75, loss = 1.08900387
# Validation score: 0.554517
# Iteration 76, loss = 1.08731493
# Validation score: 0.548287
# Iteration 77, loss = 1.08755228
# Validation score: 0.548287
# Iteration 78, loss = 1.08661040
# Validation score: 0.545171
# Iteration 79, loss = 1.08557437
# Validation score: 0.566978
# Iteration 80, loss = 1.08511916
# Validation score: 0.545171
# Iteration 81, loss = 1.08536632
# Validation score: 0.563863
# Iteration 82, loss = 1.08426615
# Validation score: 0.570093
# Iteration 83, loss = 1.08364968
# Validation score: 0.573209
# Iteration 84, loss = 1.08348725
# Validation score: 0.554517
# Iteration 85, loss = 1.08371044
# Validation score: 0.554517
# Iteration 86, loss = 1.08279328
# Validation score: 0.560748
# Iteration 87, loss = 1.08170804
# Validation score: 0.570093
# Iteration 88, loss = 1.08175961
# Validation score: 0.566978
# Iteration 89, loss = 1.08089985
# Validation score: 0.576324
# Iteration 90, loss = 1.08112817
# Validation score: 0.573209
# Iteration 91, loss = 1.07987176
# Validation score: 0.560748
# Iteration 92, loss = 1.07965764
# Validation score: 0.570093
# Iteration 93, loss = 1.07933286
# Validation score: 0.570093
# Iteration 94, loss = 1.07846540
# Validation score: 0.563863
# Iteration 95, loss = 1.07809898
# Validation score: 0.551402
# Validation score did not improve more than tol=0.000100 for 75 consecutive epochs. Stopping.
# Iteration 1, loss = 2.12061973
# Validation score: 0.339564
# Iteration 2, loss = 1.47751409
# Validation score: 0.479751
# Iteration 3, loss = 1.31356677
# Validation score: 0.520249
# Iteration 4, loss = 1.26474229
# Validation score: 0.542056
# Iteration 5, loss = 1.24125760
# Validation score: 0.538941
# Iteration 6, loss = 1.22421033
# Validation score: 0.542056
# Iteration 7, loss = 1.21253777
# Validation score: 0.542056
# Iteration 8, loss = 1.20276421
# Validation score: 0.542056
# Iteration 9, loss = 1.19464754
# Validation score: 0.545171
# Iteration 10, loss = 1.18824975
# Validation score: 0.545171
# Iteration 11, loss = 1.18278005
# Validation score: 0.542056
# Iteration 12, loss = 1.17852034
# Validation score: 0.551402
# Iteration 13, loss = 1.17456730
# Validation score: 0.535826
# Iteration 14, loss = 1.16942298
# Validation score: 0.526480
# Iteration 15, loss = 1.16607645
# Validation score: 0.542056
# Iteration 16, loss = 1.16187138
# Validation score: 0.538941
# Iteration 17, loss = 1.15914441
# Validation score: 0.529595
# ...
# Validation score: 0.601246
# Iteration 18, loss = 0.97880881
# Validation score: 0.595016
# Iteration 19, loss = 0.97535899
# Validation score: 0.591900
# Iteration 20, loss = 0.97143462
# Validation score: 0.595016
# Iteration 21, loss = 0.96865865
# Validation score: 0.595016
# Iteration 22, loss = 0.96488166
# Validation score: 0.604361
# Iteration 23, loss = 0.96352042
# Validation score: 0.607477
# Iteration 24, loss = 0.96064540
# Validation score: 0.604361
# Iteration 25, loss = 0.95817087
# Validation score: 0.604361
# Iteration 26, loss = 0.95451932
# Validation score: 0.598131
# Iteration 27, loss = 0.95349954
# Validation score: 0.601246
# Iteration 28, loss = 0.95115380
# Validation score: 0.598131
# Iteration 29, loss = 0.94891291
# Validation score: 0.601246
# Iteration 30, loss = 0.94669942
# Validation score: 0.604361
# Iteration 31, loss = 0.94553058
# Validation score: 0.604361
# Iteration 32, loss = 0.94326997
# Validation score: 0.607477
# Iteration 33, loss = 0.94142512
# Validation score: 0.607477
# Iteration 34, loss = 0.93968572
# Validation score: 0.604361
# Iteration 35, loss = 0.93872855
# Validation score: 0.607477
# Iteration 36, loss = 0.93802646
# Validation score: 0.598131
# Iteration 37, loss = 0.93496532
# Validation score: 0.604361
# Iteration 38, loss = 0.93433843
# Validation score: 0.598131
# Iteration 39, loss = 0.93386822
# Validation score: 0.598131
# Iteration 40, loss = 0.93206153
# Validation score: 0.591900
# Iteration 41, loss = 0.92965604
# Validation score: 0.595016
# Iteration 42, loss = 0.92939492
# Validation score: 0.598131
# Iteration 43, loss = 0.92877183
# Validation score: 0.598131
# Iteration 44, loss = 0.92708637
# Validation score: 0.588785
# Iteration 45, loss = 0.92653316
# Validation score: 0.595016
# Iteration 46, loss = 0.92500861
# Validation score: 0.595016
# Iteration 47, loss = 0.92415298
# Validation score: 0.585670
# Iteration 48, loss = 0.92425679
# Validation score: 0.601246
# Iteration 49, loss = 0.92206143
# Validation score: 0.598131
# Iteration 50, loss = 0.92202929
# Validation score: 0.585670
# Iteration 51, loss = 0.92133130
# Validation score: 0.588785
# Iteration 52, loss = 0.91993295
# Validation score: 0.598131
# Iteration 53, loss = 0.91903406
# Validation score: 0.591900
# Iteration 54, loss = 0.91786307
# Validation score: 0.588785
# Iteration 55, loss = 0.91677184
# Validation score: 0.591900
# Iteration 56, loss = 0.91683451
# Validation score: 0.579439
# Iteration 57, loss = 0.91627541
# Validation score: 0.588785
# Iteration 58, loss = 0.91484546
# Validation score: 0.582555
# Iteration 59, loss = 0.91469577
# Validation score: 0.591900
# Iteration 60, loss = 0.91468064
# Validation score: 0.579439
# Iteration 61, loss = 0.91438843
# Validation score: 0.588785
# Iteration 62, loss = 0.91380129
# Validation score: 0.585670
# Iteration 63, loss = 0.91247903
# Validation score: 0.582555
# Iteration 64, loss = 0.91220104
# Validation score: 0.579439
# Iteration 65, loss = 0.91097868
# Validation score: 0.573209
# Iteration 66, loss = 0.91043500
# Validation score: 0.573209
# Iteration 67, loss = 0.91057729
# Validation score: 0.570093
# Iteration 68, loss = 0.91013899
# Validation score: 0.573209
# Iteration 69, loss = 0.90959141
# Validation score: 0.582555
# Iteration 70, loss = 0.90873867
# Validation score: 0.579439
# Iteration 71, loss = 0.90908651
# Validation score: 0.588785
# Iteration 72, loss = 0.90893136
# Validation score: 0.570093
# Iteration 73, loss = 0.90658866
# Validation score: 0.566978
# Iteration 74, loss = 0.90675760
# Validation score: 0.576324
# Iteration 75, loss = 0.90698312
# Validation score: 0.570093
# Iteration 76, loss = 0.90547922
# Validation score: 0.576324
# Iteration 77, loss = 0.90641111
# Validation score: 0.573209
# Iteration 78, loss = 0.90505475
# Validation score: 0.566978
# Iteration 79, loss = 0.90460864
# Validation score: 0.566978
# Iteration 80, loss = 0.90460325
# Validation score: 0.579439
# Iteration 81, loss = 0.90537918
# Validation score: 0.570093
# Iteration 82, loss = 0.90347225
# Validation score: 0.573209
# Iteration 83, loss = 0.90422468
# Validation score: 0.576324
# Validation score did not improve more than tol=0.000100 for 75 consecutive epochs. Stopping.
# Iteration 1, loss = 2.14834792
# Validation score: 0.339564
# Iteration 2, loss = 1.48336918
# Validation score: 0.485981
# Iteration 3, loss = 1.28789864
# Validation score: 0.532710
# Iteration 4, loss = 1.21404413
# Validation score: 0.566978
# Iteration 5, loss = 1.17194853
# Validation score: 0.566978
# Iteration 6, loss = 1.14460725
# Validation score: 0.566978
# Iteration 7, loss = 1.12464463
# Validation score: 0.573209
# Iteration 8, loss = 1.10983391
# Validation score: 0.579439
# Iteration 9, loss = 1.09747373
# Validation score: 0.582555
# Iteration 10, loss = 1.08779831
# Validation score: 0.588785
# Iteration 11, loss = 1.08073563
# Validation score: 0.598131
# Iteration 12, loss = 1.07628340
# Validation score: 0.591900
# Iteration 13, loss = 1.07014668
# Validation score: 0.598131
# Iteration 14, loss = 1.06510694
# Validation score: 0.601246
# Iteration 15, loss = 1.06180302
# Validation score: 0.607477
# Iteration 16, loss = 1.05727037
# Validation score: 0.607477
# Iteration 17, loss = 1.05444694
# Validation score: 0.604361
# Iteration 18, loss = 1.05203139
# Validation score: 0.607477
# Iteration 19, loss = 1.04912822
# Validation score: 0.604361
# Iteration 20, loss = 1.04459952
# Validation score: 0.601246
# Iteration 21, loss = 1.04257026
# Validation score: 0.601246
# Iteration 22, loss = 1.03986449
# Validation score: 0.601246
# Iteration 23, loss = 1.03681911
# Validation score: 0.601246
# Iteration 24, loss = 1.03521448
# Validation score: 0.607477
# Iteration 25, loss = 1.03272593
# Validation score: 0.601246
# Iteration 26, loss = 1.02990714
# Validation score: 0.591900
# Iteration 27, loss = 1.02844077
# Validation score: 0.604361
# Iteration 28, loss = 1.02701902
# Validation score: 0.598131
# Iteration 29, loss = 1.02410983
# Validation score: 0.601246
# Iteration 30, loss = 1.02273348
# Validation score: 0.610592
# Iteration 31, loss = 1.02025489
# Validation score: 0.604361
# Iteration 32, loss = 1.01929707
# Validation score: 0.610592
# Iteration 33, loss = 1.01831342
# Validation score: 0.613707
# Iteration 34, loss = 1.01650464
# Validation score: 0.598131
# Iteration 35, loss = 1.01461864
# Validation score: 0.610592
# Iteration 36, loss = 1.01409908
# Validation score: 0.607477
# Iteration 37, loss = 1.01264564
# Validation score: 0.604361
# Iteration 38, loss = 1.01039873
# Validation score: 0.601246
# Iteration 39, loss = 1.00950582
# Validation score: 0.604361
# Iteration 40, loss = 1.00837010
# Validation score: 0.610592
# Iteration 41, loss = 1.00680662
# Validation score: 0.601246
# Iteration 42, loss = 1.00652452
# Validation score: 0.591900
# Iteration 43, loss = 1.00493460
# Validation score: 0.604361
# Iteration 44, loss = 1.00449424
# Validation score: 0.604361
# Iteration 45, loss = 1.00398064
# Validation score: 0.604361
# Iteration 46, loss = 1.00232249
# Validation score: 0.601246
# Iteration 47, loss = 1.00132209
# Validation score: 0.598131
# Iteration 48, loss = 1.00023214
# Validation score: 0.601246
# Iteration 49, loss = 0.99945180
# Validation score: 0.598131
# Iteration 50, loss = 0.99830855
# Validation score: 0.595016
# Iteration 51, loss = 0.99824954
# Validation score: 0.591900
# Iteration 52, loss = 0.99704020
# Validation score: 0.595016
# Iteration 53, loss = 0.99569910
# Validation score: 0.604361
# Iteration 54, loss = 0.99449492
# Validation score: 0.598131
# Iteration 55, loss = 0.99320882
# Validation score: 0.601246
# Iteration 56, loss = 0.99324643
# Validation score: 0.598131
# Iteration 57, loss = 0.99225393
# Validation score: 0.591900
# Iteration 58, loss = 0.99109834
# Validation score: 0.591900
# Iteration 59, loss = 0.99072149
# Validation score: 0.595016
# Iteration 60, loss = 0.99060748
# Validation score: 0.595016
# Iteration 61, loss = 0.98956134
# Validation score: 0.585670
# Iteration 62, loss = 0.98776720
# Validation score: 0.579439
# Iteration 63, loss = 0.98751931
# Validation score: 0.598131
# Iteration 64, loss = 0.98720417
# Validation score: 0.595016
# Iteration 65, loss = 0.98631604
# Validation score: 0.582555
# Iteration 66, loss = 0.98557848
# Validation score: 0.588785
# Iteration 67, loss = 0.98476815
# Validation score: 0.570093
# Iteration 68, loss = 0.98314798
# Validation score: 0.582555
# Iteration 69, loss = 0.98311664
# Validation score: 0.591900
# Iteration 70, loss = 0.98169433
# Validation score: 0.582555
# Iteration 71, loss = 0.98144674
# Validation score: 0.588785
# Iteration 72, loss = 0.97986473
# Validation score: 0.579439
# Iteration 73, loss = 0.98008834
# Validation score: 0.585670
# Iteration 74, loss = 0.97814980
# Validation score: 0.582555
# Iteration 75, loss = 0.97790077
# Validation score: 0.582555
# Iteration 76, loss = 0.97807753
# Validation score: 0.576324
# Iteration 77, loss = 0.97664405
# Validation score: 0.579439
# Iteration 78, loss = 0.97712924
# Validation score: 0.582555
# Iteration 79, loss = 0.97638028
# Validation score: 0.576324
# Iteration 80, loss = 0.97554839
# Validation score: 0.576324
# Iteration 81, loss = 0.97535445
# Validation score: 0.573209
# Iteration 82, loss = 0.97368206
# Validation score: 0.573209
# Iteration 83, loss = 0.97370845
# Validation score: 0.579439
# Iteration 84, loss = 0.97194652
# Validation score: 0.563863
# Iteration 85, loss = 0.97259317
# Validation score: 0.573209
# Iteration 86, loss = 0.97104323
# Validation score: 0.579439
# Iteration 87, loss = 0.97129510
# Validation score: 0.566978
# Iteration 88, loss = 0.97044315
# Validation score: 0.566978
# Iteration 89, loss = 0.97008849
# Validation score: 0.563863
# Iteration 90, loss = 0.96983181
# Validation score: 0.570093
# Iteration 91, loss = 0.96813182
# Validation score: 0.563863
# Iteration 92, loss = 0.96834377
# Validation score: 0.560748
# Iteration 93, loss = 0.96779895
# Validation score: 0.560748
# Iteration 94, loss = 0.96731178
# Validation score: 0.570093
# Iteration 95, loss = 0.96679856
# Validation score: 0.563863
# Iteration 96, loss = 0.96666862
# Validation score: 0.570093
# Iteration 97, loss = 0.96636157
# Validation score: 0.563863
# Iteration 98, loss = 0.96548537
# Validation score: 0.560748
# Iteration 99, loss = 0.96532473
# Validation score: 0.570093
# Iteration 100, loss = 0.96363978
# Validation score: 0.570093
# Iteration 101, loss = 0.96409676
# Validation score: 0.563863
# Iteration 102, loss = 0.96397243
# Validation score: 0.570093
# Iteration 103, loss = 0.96316437
# Validation score: 0.566978
# Iteration 104, loss = 0.96373910
# Validation score: 0.566978
# Iteration 105, loss = 0.96264574
# Validation score: 0.560748
# Iteration 106, loss = 0.96385631
# Validation score: 0.554517
# Iteration 107, loss = 0.96200483
# Validation score: 0.563863
# Iteration 108, loss = 0.96269768
# Validation score: 0.557632
# Iteration 109, loss = 0.96180927
# Validation score: 0.560748
# Validation score did not improve more than tol=0.000100 for 75 consecutive epochs. Stopping.
# Iteration 1, loss = 2.02269662
# Validation score: 0.277259
# Iteration 2, loss = 1.77129854
# Validation score: 0.364486
# Iteration 3, loss = 1.69707944
# Validation score: 0.383178
# Iteration 4, loss = 1.66401800
# Validation score: 0.386293
# Iteration 5, loss = 1.64243853
# Validation score: 0.386293
# Iteration 6, loss = 1.62546636
# Validation score: 0.386293
# Iteration 7, loss = 1.61322114
# Validation score: 0.389408
# Iteration 8, loss = 1.60127048
# Validation score: 0.389408
# Iteration 9, loss = 1.59217685
# Validation score: 0.383178
# Iteration 10, loss = 1.58381203
# Validation score: 0.380062
# Iteration 11, loss = 1.57588743
# Validation score: 0.383178
# Iteration 12, loss = 1.56951838
# Validation score: 0.383178
# Iteration 13, loss = 1.56255566
# Validation score: 0.386293
# Iteration 14, loss = 1.55743731
# Validation score: 0.386293
# Iteration 15, loss = 1.55124270
# Validation score: 0.389408
# Iteration 16, loss = 1.54599108
# Validation score: 0.386293
# Iteration 17, loss = 1.54207207
# Validation score: 0.386293
# Iteration 18, loss = 1.53792915
# Validation score: 0.383178
# Iteration 19, loss = 1.53498723
# Validation score: 0.389408
# Iteration 20, loss = 1.53155489
# Validation score: 0.386293
# Iteration 21, loss = 1.52772689
# Validation score: 0.386293
# Iteration 22, loss = 1.52292793
# Validation score: 0.386293
# Iteration 23, loss = 1.51983505
# Validation score: 0.389408
# Iteration 24, loss = 1.51736177
# Validation score: 0.386293
# Iteration 25, loss = 1.51570172
# Validation score: 0.383178
# Iteration 26, loss = 1.51146081
# Validation score: 0.386293
# Iteration 27, loss = 1.50920879
# Validation score: 0.386293
# Iteration 28, loss = 1.50746542
# Validation score: 0.389408
# Iteration 29, loss = 1.50496406
# Validation score: 0.383178
# Iteration 30, loss = 1.50275966
# Validation score: 0.376947
# Iteration 31, loss = 1.50098026
# Validation score: 0.380062
# Iteration 32, loss = 1.49860202
# Validation score: 0.370717
# Iteration 33, loss = 1.49785342
# Validation score: 0.373832
# Iteration 34, loss = 1.49600594
# Validation score: 0.383178
# Iteration 35, loss = 1.49471987
# Validation score: 0.380062
# Iteration 36, loss = 1.49201549
# Validation score: 0.383178
# Iteration 37, loss = 1.49111087
# Validation score: 0.380062
# Iteration 38, loss = 1.49030246
# Validation score: 0.383178
# Iteration 39, loss = 1.48834464
# Validation score: 0.380062
# Iteration 40, loss = 1.48752645
# Validation score: 0.376947
# Iteration 41, loss = 1.48659283
# Validation score: 0.376947
# Iteration 42, loss = 1.48496466
# Validation score: 0.380062
# Iteration 43, loss = 1.48379754
# Validation score: 0.373832
# Iteration 44, loss = 1.48306160
# Validation score: 0.370717
# Iteration 45, loss = 1.48182987
# Validation score: 0.373832
# Iteration 46, loss = 1.48066008
# Validation score: 0.373832
# Iteration 47, loss = 1.48051651
# Validation score: 0.373832
# Iteration 48, loss = 1.48023449
# Validation score: 0.373832
# Iteration 49, loss = 1.47800593
# Validation score: 0.367601
# Iteration 50, loss = 1.47828966
# Validation score: 0.367601
# Iteration 51, loss = 1.47632752
# Validation score: 0.376947
# Iteration 52, loss = 1.47617115
# Validation score: 0.367601
# Iteration 53, loss = 1.47546815
# Validation score: 0.370717
# Iteration 54, loss = 1.47404594
# Validation score: 0.364486
# Iteration 55, loss = 1.47367881
# Validation score: 0.364486
# Iteration 56, loss = 1.47299406
# Validation score: 0.358255
# Iteration 57, loss = 1.47253324
# Validation score: 0.367601
# Iteration 58, loss = 1.47118235
# Validation score: 0.364486
# Iteration 59, loss = 1.47047336
# Validation score: 0.370717
# Iteration 60, loss = 1.47047047
# Validation score: 0.380062
# Iteration 61, loss = 1.46955966
# Validation score: 0.367601
# Iteration 62, loss = 1.46867323
# Validation score: 0.370717
# Iteration 63, loss = 1.46766755
# Validation score: 0.370717
# Iteration 64, loss = 1.46749211
# Validation score: 0.370717
# Iteration 65, loss = 1.46637012
# Validation score: 0.367601
# Iteration 66, loss = 1.46594608
# Validation score: 0.367601
# Iteration 67, loss = 1.46503348
# Validation score: 0.370717
# Iteration 68, loss = 1.46393725
# Validation score: 0.370717
# Iteration 69, loss = 1.46440832
# Validation score: 0.376947
# Iteration 70, loss = 1.46295290
# Validation score: 0.380062
# Iteration 71, loss = 1.46173004
# Validation score: 0.376947
# Iteration 72, loss = 1.46258398
# Validation score: 0.373832
# Iteration 73, loss = 1.46044589
# Validation score: 0.383178
# Iteration 74, loss = 1.46098555
# Validation score: 0.376947
# Iteration 75, loss = 1.46001324
# Validation score: 0.386293
# Iteration 76, loss = 1.45966917
# Validation score: 0.380062
# Iteration 77, loss = 1.45856545
# Validation score: 0.380062
# Iteration 78, loss = 1.45839918
# Validation score: 0.380062
# Iteration 79, loss = 1.45735454
# Validation score: 0.386293
# Iteration 80, loss = 1.45696470
# Validation score: 0.380062
# Iteration 81, loss = 1.45621996
# Validation score: 0.383178
# Iteration 82, loss = 1.45507662
# Validation score: 0.389408
# Iteration 83, loss = 1.45549746
# Validation score: 0.383178
# Validation score did not improve more than tol=0.000100 for 75 consecutive epochs. Stopping.
# MultiOutputClassifier(estimator=MLPClassifier(batch_size=8, early_stopping=True,
#                                               hidden_layer_sizes=[16],
#                                               max_iter=5000,
#                                               n_iter_no_change=75,
#                                               random_state=42,
#                                               validation_fraction=0.2,
#                                               verbose=True))

# %%
# Predizioni del modello multi-target
y_pred_trainval = multi_target_mlp1.predict(X_trainval)  # Predizioni training+validation
y_pred = multi_target_mlp1.predict(X_test)              # Predizioni test set

# Dizionari per memorizzare l'accuratezza per ogni droga
train_accuracies = {}
test_accuracies = {}

for i, drug in enumerate(target_columns):
    # Accuratezza per training+validation set
    acc_trainval = accuracy_score(y_trainval.iloc[:, i], y_pred_trainval[:, i])
    train_accuracies[drug] = acc_trainval
    
    # Accuratezza per test set
    acc_test = accuracy_score(y_test.iloc[:, i], y_pred[:, i])
    test_accuracies[drug] = acc_test

# DataFrame: droghe come colonne, train/test come righe
df_accuracy = pd.DataFrame([train_accuracies, test_accuracies], 
                          index=['Train+Val', 'Test'])

# Accuratezza media
mean_acc_trainval = df_accuracy.loc['Train+Val'].mean()
mean_acc_test = df_accuracy.loc['Test'].mean()

# Colonna con medie
df_accuracy['MEDIA'] = [mean_acc_trainval, mean_acc_test]
display(df_accuracy.round(4))
# Out:
#            Alcohol  Amphet  Caffeine  Cannabis    Choc    Coke  Ecstasy  \
# Train+Val   0.4195  0.5618    0.7372    0.4663  0.4744  0.5793   0.5762
# Test        0.3710  0.4735    0.7279    0.4240  0.3958  0.5760   0.5406
#
#               LSD  Mushrooms  Nicotine   MEDIA
# Train+Val  0.6117     0.5961    0.4014  0.5424
# Test       0.5830     0.5124    0.3640  0.4968

# %%
# Estraiamo 3 campioni casuali dal test set e analizziamo le previsioni

drug_names_short = []
for drug in target_columns:
   if len(drug) <= 4:
       drug_names_short.append(drug)
   else:
       drug_names_short.append(drug[:4])  # Prime 4 lettere

n_randsamples = 3
ind_test_rand = np.random.choice(len(y_test), n_randsamples, replace=False)

rand_samples_pca = X_test[ind_test_rand, :]
rand_targets = y_test.iloc[ind_test_rand]

y_pred_rand_samples = multi_target_mlp1.predict(rand_samples_pca)

try:
   rand_samples_proba = []
   for estimator in multi_target_mlp1.estimators_:
       proba = estimator.predict_proba(rand_samples_pca)
       rand_samples_proba.append(proba)
except:
   rand_samples_proba = None

for i in range(n_randsamples):
   fig, axs = plt.subplots(1, 2, figsize=(12, 5))
   
   axs[0].bar(np.arange(len(target_columns)), rand_targets.iloc[i], alpha=0.7, label='Reale')
   axs[0].bar(np.arange(len(target_columns)), y_pred_rand_samples[i], alpha=0.7, label='Predetto')
   axs[0].set_xticks(np.arange(len(target_columns)))
   axs[0].set_xticklabels(drug_names_short, rotation=45, fontsize=10)
   axs[0].set_ylabel('Livello uso (0-6)')
   axs[0].set_title(f'Campione {ind_test_rand[i]}: Reale vs Predetto')
   axs[0].legend()
   axs[0].grid(alpha=0.3)
   
   errors = rand_targets.iloc[i] - y_pred_rand_samples[i]
   colors = ['red' if x != 0 else 'green' for x in errors]
   axs[1].bar(np.arange(len(target_columns)), errors, color=colors, alpha=0.7)
   axs[1].set_xticks(np.arange(len(target_columns)))
   axs[1].set_xticklabels(drug_names_short, rotation=45, fontsize=10)
   axs[1].set_ylabel('Errore (Reale - Predetto)')
   axs[1].set_title('Errori per droga')
   axs[1].axhline(y=0, color='black', linewidth=0.8)
   axs[1].grid(alpha=0.3)
   
   plt.tight_layout()
   plt.show()

# %% [markdown]
# ### Binary classification
#
# Al fine di ottenere una migliore accuratezza abbiamo semplificato notevolmente il problema.
# Passiamo dal fare una classificazaione multi-classe e multi-output ad un problema elementare: selezioniamo una delle sostanze per cui il dataset è meglio bilanciato, **la cannabis**, e raggruppiamo le classi sotto due etichette. Il nuovo problema sarà quello di fare **classificazione binaria**, e lo svolgeremo con due approcci differenti

# %%
# Creiamo una copia del dataset per la classificazione binaria
drugs_Cannabis_binary = drugs.copy()

# Calcoliamo la mediana della frequenza di utilizzo della Cannabis
median_Cannabis = drugs['Cannabis'].median()
print(f"Mediana della frequenza di utilizzo della Cannabis: {median_Cannabis}")

n_ones = (drugs_Cannabis_binary['Cannabis'] > median_Cannabis).sum()
n_zeros = (drugs_Cannabis_binary['Cannabis'] < median_Cannabis).sum()

# Le classi di utilizzo sopra alla medina le considero come "Alto utilizzo" (1)
# Le classi di utilizzo sotto alla mediana le considero come "Basso utilizzo" (0)
# La classe di utilizzo che sta sulla mediana, la associo alla divisione binaria con meno rappresentanti

if(n_ones > n_zeros):
    drugs_Cannabis_binary['Cannabis_binary'] = (drugs_Cannabis_binary['Cannabis'] > median_Cannabis).astype(int)
else:
    drugs_Cannabis_binary['Cannabis_binary'] = (drugs_Cannabis_binary['Cannabis'] >= median_Cannabis).astype(int)

# Distribuzione finale
final_counts = drugs_Cannabis_binary['Cannabis_binary'].value_counts()
print(f"\nDistribuzione finale:")
print(f"Classe 0: {final_counts[0]} campioni")
print(f"Classe 1: {final_counts[1]} campioni")

# Frequenze relative finali
freq_binary = drugs_Cannabis_binary['Cannabis_binary'].value_counts(normalize=True)
print(f"\nFrequenze relative finali:")
print(f"Basso utilizzo (0): {freq_binary[0]:.2%}")
print(f"Alto utilizzo (1): {freq_binary[1]:.2%}")
# Out:
# Mediana della frequenza di utilizzo della Cannabis: 3.0
#
# Distribuzione finale:
# Classe 0: 886 campioni
# Classe 1: 999 campioni
#
# Frequenze relative finali:
# Basso utilizzo (0): 47.00%
# Alto utilizzo (1): 53.00%

# %%
target_column = 'Cannabis_binary'  

# Estraiamo features e target
X_cb = drugs_Cannabis_binary[feature_columns].copy()
y_cb = drugs_Cannabis_binary[target_column].copy()

# Diviamo test set e validation + training set
test_size=0.15
validation_size = 0.2
training_size = 0.65

X_trainval_cb, X_test_cb, y_trainval_cb, y_test_cb = train_test_split(
X_cb, y_cb, 
test_size=test_size,
random_state=42,
shuffle=True
)

# %%
mlp = MLPClassifier(
    hidden_layer_sizes=[2,4],
    activation='relu',
    solver='lbfgs',                     # Solver diverso per dataset piccoli
    alpha=0.01,
    max_iter=6000,
    n_iter_no_change=30,                    
    random_state=42,
    verbose=True
)

mlp.fit(X_trainval_cb, y_trainval_cb)
# Out:
# MLPClassifier(alpha=0.01, hidden_layer_sizes=[2, 4], max_iter=6000,
#               n_iter_no_change=30, random_state=42, solver='lbfgs',
#               verbose=True)

# %%
# Performance del modello
y_pred_trainval_cb = mlp.predict(X_trainval_cb)
y_pred_test_cb = mlp.predict(X_test_cb)

# Accuratezza per training+validation e test set
acc_trainval = accuracy_score(y_trainval_cb, y_pred_trainval_cb)
acc_test = accuracy_score(y_test_cb, y_pred_test_cb)

# DataFrame con le performance
performance_df = pd.DataFrame({
    'Accuracy': [acc_trainval, acc_test]
}, index=['Train+Val', 'Test'])

print("PERFORMANCE DEL CLASSIFICATORE MLP CANNABIS BINARIA")
print("=" * 50)
display(performance_df.round(4))

# Matrice di confusione
cm_test = confusion_matrix(y_test_cb, y_pred_test_cb)
cm_df = pd.DataFrame(cm_test,
                     columns=['Predetto: 0', 'Predetto: 1'],
                     index=['Reale: 0', 'Reale: 1'])

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Grafico a barre dell'accuratezza
train_test = ['Train+Val', 'Test']
accuracies = [acc_trainval, acc_test]

axes[0].bar(train_test, accuracies, alpha=0.8, color=['skyblue', 'lightcoral'])
axes[0].set_ylabel('Accuracy')
axes[0].set_title('Accuratezza del Classificatore MLP')
axes[0].grid(True, alpha=0.3)

for i, v in enumerate(accuracies):
    axes[0].text(i, v + 0.01, f'{v:.3f}', ha='center', va='bottom')

# Heatmap della matrice di confusione
sns.heatmap(cm_df, annot=True, fmt='d', cmap='Blues', ax=axes[1])
axes[1].set_title('Matrice di Confusione (Test Set)')

plt.tight_layout()
plt.show()

# Informazioni aggiuntive sul training
print(f"\nINFORMAZIONI TRAINING:")
print(f"Numero di epoche eseguite: {mlp.n_iter_}")
print(f"Loss finale: {mlp.loss_:.6f}")
# Out:
# PERFORMANCE DEL CLASSIFICATORE MLP CANNABIS BINARIA
# ==================================================
#            Accuracy
# Train+Val    0.8202
# Test         0.8233
# INFORMAZIONI TRAINING:
# Numero di epoche eseguite: 419
# Loss finale: 0.394384

# %% [markdown]
# # Support Vector Machines (SVMs)
#
# ## Idee generali e obiettivo
#
# Le Support Vector Machines rappresentano uno degli algoritmi di machine learning per la classificazione. L'idea centrale è semplice: quando dobbiamo separare due classi di dati, invece di accontentarci di qualsiasi linea di separazione che funzioni, cerchiamo quella "migliore" possibile.
#
# Ma cosa significa "migliore": Gli SVM introducono il concetto di *margine massimo: la linea di separazione ottimale è quella che massimizza la distanza dalle osservazioni più vicine di entrambe le classi. Queste osservazioni critiche, che "toccano" i confini del margine, sono chiamate **support vectors* e danno il nome all'algoritmo.
#
# Un aspetto profondo degli SVM è il *kernel trick*, che permette di risolvere problemi non lineari trasformandoli matematicamente in spazi di dimensioni superiori dove diventano lineari, senza mai calcolare esplicitamente questa trasformazione.
#
# ## Hard SVM e Soft SVM
#
# ### Dataset e Notazione
# Consideriamo un dataset $S = \{(\mathbf{x}_1, y_1), \ldots, (\mathbf{x}_m, y_m)\}$ dove:
# - $\mathbf{x}_i \in \mathbb{R}^d$ sono i vettori delle features
# - $y_i \in \{+1, -1\}$ sono le etichette delle classi
# - $m = |S|$ è la dimensione del dataset
#
# ### Iperpiano Separatore
# Definiamo l'iperpiano $H_{\boldsymbol{\omega},b}$ come:
# $$H_{\boldsymbol{\omega},b} = \{\mathbf{x} \in \mathbb{R}^d \mid \boldsymbol{\omega}^T \mathbf{x} + b = 0\}$$
#
# dove:
# - $\boldsymbol{\omega} \in \mathbb{R}^d$ è il vettore normale all'iperpiano
# - $b \in \mathbb{R}$ è il termine di bias
#
# ### Etichettatura delle Classi
# $$y_i = \begin{cases}
# +1 & \text{se } \mathbf{x}_i \in \text{Classe 1} \\
# -1 & \text{se } \mathbf{x}_i \in \text{Classe 2}
# \end{cases}$$
#
# ### Distanza dall'iperpiano
# La distanza euclidea di un punto $\mathbf{x}$ dall'iperpiano è:
# $$\text{dist}(H_{\boldsymbol{\omega},b}, \mathbf{x}) = \frac{|\boldsymbol{\omega}^T \mathbf{x} + b|}{||\boldsymbol{\omega}||}$$
#
# ## Hard SVM (Margine Rigido)
#
# ### Definizione del Margine
# Il **margine** è la minima distanza tra l'iperpiano e i punti del dataset:
# $$M_{\boldsymbol{\omega},b} = 2 \cdot \min_{\mathbf{x} \in S} \text{dist}(H_{\boldsymbol{\omega},b}, \mathbf{x})$$
#
# ### Support Vectors
# Un vettore $\mathbf{x}_i$ è chiamato **support vector** se si trova sul margine. I support vectors sono i punti più importanti perché determinano completamente l'iperpiano separatore.
#
# ### Problema di Ottimizzazione
#
# #### Formulazione Intuitiva
# Cerchiamo di massimizzare il margine:
# $$\arg \max_{(\boldsymbol{\omega}, b) : ||\boldsymbol{\omega}|| = 1} \min_{i \in \{1,\ldots,m\}} |\langle\boldsymbol{\omega}, \mathbf{x}_i\rangle + b|$$
#
# soggetto a:
# $$y_i(\langle\boldsymbol{\omega}, \mathbf{x}_i\rangle + b) > 0, \quad \forall i = 1, \ldots, m$$
#
# #### Formulazione Standard
# Equivalentemente, possiamo **minimizzare** $||\boldsymbol{\omega}||^2$ (che massimizza il margine):
#
# $$\arg \min_{\boldsymbol{\omega}, b} \frac{1}{2}||\boldsymbol{\omega}||^2$$
#
# soggetto a:
# $$y_i(\langle\boldsymbol{\omega}, \mathbf{x}_i\rangle + b) \geq 1, \quad \forall i = 1, \ldots, m$$
#
# ### Problema Duale
# Applicando i moltiplicatori di Lagrange e le condizioni KKT:
#
# $$\max_{\boldsymbol{\alpha}} \sum_{i=1}^m \alpha_i - \frac{1}{2} \sum_{i,j=1}^m \alpha_i \alpha_j y_i y_j \langle\mathbf{x}_i, \mathbf{x}_j\rangle$$
#
# soggetto a:
# - $\sum_{i=1}^m \alpha_i y_i = 0$
# - $\alpha_i \geq 0, \quad \forall i = 1, \ldots, m$
#
# ### Funzione di Decisione
# $$h(\mathbf{x}) = \text{sign}\left(\sum_{i=1}^m \alpha_i y_i \langle\mathbf{x}_i, \mathbf{x}\rangle + b\right)$$
#
# dove:
# $$b = y_j - \sum_{i=1}^m \alpha_i y_i \langle\mathbf{x}_i, \mathbf{x}_j\rangle \quad \forall\mathbf{x}_j \text{ Support Vector}$$
#
# ### Condizioni di Ottimalità
# $$\alpha_i = \begin{cases}
# 0 & \text{se } \mathbf{x}_i \text{ non è support vector} \\
# \neq 0 & \text{se } \mathbf{x}_i \text{ è support vector}
# \end{cases}$$
#
#
# ## Soft SVM (Margine Morbido)
#
# ### Motivazione
# Spesso è difficile o impossibile separare perfettamente i dati con un iperpiano. La **Hard SVM** non ammette violazioni del margine, mentre la **Soft SVM** permette alcune violazioni controllate.
#
# ### Variabili Slack
# Introduciamo le **variabili slack** $\xi_i \geq 0$ che rappresentano il "prezzo da pagare" per attraversare il margine:
#
# - $\xi_i = 0$: punto correttamente classificato fuori dal margine
# - $0 < \xi_i < 1$: punto correttamente classificato ma dentro il margine
# - $\xi_i \geq 1$: punto misclassificato
#
# ### Problema di Ottimizzazione
#
# $$\arg \min_{\boldsymbol{\omega}, b, \boldsymbol{\xi}} \frac{1}{2}||\boldsymbol{\omega}||^2 + C \sum_{i=1}^m \xi_i$$
#
# soggetto a:
# - $y_i(\langle\boldsymbol{\omega}, \mathbf{x}_i\rangle + b) \geq 1 - \xi_i, \quad \forall i = 1, \ldots, m$
# - $\xi_i \geq 0, \quad \forall i = 1, \ldots, m$
#
# ### Parametro di Regolarizzazione C
#
# Il parametro $C$ controlla il **trade-off** tra:
# - **Massimizzazione del margine**: termine $\frac{1}{2}||\boldsymbol{\omega}||^2$
# - **Minimizzazione degli errori**: termine $C \sum_{i=1}^m \xi_i$
#
# #### Comportamento di C:
# - **$C \to 0$**: margine massimo, molte violazioni permesse (underfitting)
# - **$C \to \infty$**: si avvicina alla Hard SVM, poche violazioni (overfitting)
# - **$C$ intermedio**: bilanciamento ottimale
#
# ### Problema Duale
# $$\max_{\boldsymbol{\alpha}} \sum_{i=1}^m \alpha_i - \frac{1}{2} \sum_{i,j=1}^m \alpha_i \alpha_j y_i y_j \langle\mathbf{x}_i, \mathbf{x}_j\rangle$$
#
# soggetto a:
# - $\sum_{i=1}^m \alpha_i y_i = 0$
# - $0 \leq \alpha_i \leq C, \quad \forall i = 1, \ldots, m$
#
# **Differenza chiave**: ora abbiamo il vincolo superiore $\alpha_i \leq C$.
#
# ### Funzione di Decisione
# $$h(\mathbf{x}) = \text{sign}\left(\sum_{i=1}^m \alpha_i y_i \langle\mathbf{x}_i, \mathbf{x}\rangle + b\right)$$
#
# dove:
# $$b = y_i - \sum_{j=1}^m \alpha_j y_j \langle\mathbf{x}_j, \mathbf{x}_i\rangle \quad \forall\mathbf{x}_i \text{ con } 0 < \alpha_i < C$$
#
# ### Classificazione dei Support Vectors
# $$\alpha_i = \begin{cases}
# 0 & \text{se } \mathbf{x}_i \text{ non è support vector} \\
# 0 < \alpha_i < C & \text{se } \mathbf{x}_i \text{ è support vector sul margine} \\
# \alpha_i = C & \text{se } \mathbf{x}_i \text{ è support vector che viola il margine}
# \end{cases}$$
#
#
# ## Osservazioni
#
# 1. **La Soft SVM generalizza la Hard SVM**: quando $C \to \infty$, la Soft SVM converge alla Hard SVM.
#
# 2. **I support vectors determinano completamente la soluzione**: solo i punti con $\alpha_i > 0$ influenzano la funzione di decisione.
#
# 3. **Il kernel trick si applica a entrambe**: sostituendo $\langle\mathbf{x}_i, \mathbf{x}_j\rangle$ con $K(\mathbf{x}_i, \mathbf{x}_j)$ possiamo gestire problemi non lineari.
#
# 4. **La scelta di $C$ è cruciale**: richiede validazione incrociata per trovare il valore ottimale.
# ## Il Kernel Trick
#
# ### Motivazione
# La separazione lineare è spesso insufficiente. Il kernel trick permette di mappare i dati in uno spazio di dimensioni superiori $\Phi : X \rightarrow F$ dove possono diventare linearmente separabili, senza calcolare esplicitamente la mappatura.
#
# ### Definizione
# Una *funzione kernel* $K : X \times X \rightarrow \mathbb{R}$ soddisfa:
# $$K(\mathbf{x}_i, \mathbf{x}_j) = \langle \Phi(\mathbf{x}_i), \Phi(\mathbf{x}_j) \rangle$$
#
# ### Condizione PDS (Positive Definite Symmetric)
# Un kernel è valido se per qualsiasi insieme $\{\mathbf{x}1, \ldots, \mathbf{x}_m\} \subseteq X$, la matrice di Gram $\mathbf{K} = [K(\mathbf{x}_i, \mathbf{x}_j)]{ij}$ è simmetrica e semi-definita positiva:
#
# $$\mathbf{c}^T \mathbf{K} \mathbf{c} = \sum_{i,j=1}^m c_i c_j K(\mathbf{x}_i, \mathbf{x}_j) \geq 0 \quad \forall \mathbf{c} \in \mathbb{R}^{m}$$
#
# ### Kernels Standard
#
# *Kernel Polinomiale:*
# $$K(\mathbf{x}, \mathbf{y}) = (\langle \mathbf{x}, \mathbf{y} \rangle + c)^d, \quad c > 0$$
#
# *Kernel Gaussiano (RBF):*
# $$K(\mathbf{x}, \mathbf{y}) = \exp\left(-\frac{||\mathbf{x} - \mathbf{y}||^2}{2\sigma^2}\right), \quad \sigma \neq 0$$
#
# *Kernel Sigmoide:*
# $$K(\mathbf{x}, \mathbf{y}) = \tanh(a(\mathbf{x} \cdot \mathbf{y}) + b), \quad a, b \geq 0$$
#
# ### Esempio: Kernel Polinomiale di Grado 2
# Per $\mathbf{x} = [x_1, x_2]$ e $d = 2$:
#
# $$K(\mathbf{x}, \mathbf{y}) = (\mathbf{x} \cdot \mathbf{y} + c)^2$$
#
# Espandendo:
# $$= (x_1 y_1 + x_2 y_2 + c)^2$$
# $$= \begin{bmatrix} x_1^2 \\ x_2^2 \\ \sqrt{2}x_1 x_2 \\ \sqrt{2c}x_1 \\ \sqrt{2c}x_2 \\ c \end{bmatrix}^T \begin{bmatrix} y_1^2 \\ y_2^2 \\ \sqrt{2}y_1 y_2 \\ \sqrt{2c}y_1 \\ \sqrt{2c}y_2 \\ c \end{bmatrix}$$
#
# Il kernel calcola questo prodotto scalare 6-dimensionale senza mai costruire esplicitamente i vettori trasformati!
#
# ### SVM con Kernel
# Sostituiamo $\langle \mathbf{x}_i, \mathbf{x}_j \rangle$ con $K(\mathbf{x}_i, \mathbf{x}_j)$ nella formulazione duale:
#
# $$\max_{\boldsymbol{\alpha}} \sum_{i=1}^m \alpha_i - \frac{1}{2}\sum_{i=1}^m\sum_{j=1}^m \alpha_i\alpha_j y_i y_j K(\mathbf{x}_i, \mathbf{x}_j)$$
#
# La funzione di decisione diventa:
# $$h(\mathbf{x}) = \text{sign}\left(\sum_{i=1}^m \alpha_i y_i K(\mathbf{x}, \mathbf{x}_i) + b\right)$$
#
# #### Scelta del Kernel
#
# -⁠⁠  **Lineare**: Dati già separabili o molto alta dimensionalità
#
# -⁠⁠  **Polinomiale**: Relazioni polinomiali tra features
#
# -⁠  **RBF**: Universal approximator, buon default
#
# -⁠  ⁠**Compositi**: Combinazioni per catturare pattern complessi

# %%
# Facciamo SVM con kernel RBF

# C = direzza dell'iperpiano
# gamma = varianza della gaussiana (reciproco)
# 
svm_rbf = SVC(kernel='rbf', C=1.0, gamma='scale', probability=True, random_state=42)
svm_rbf.fit(X_trainval_cb, y_trainval_cb)
y_pred_rbf = svm_rbf.predict(X_test_cb)

print(f"\nSVM RBF Base - F1 Score: {f1_score(y_test_cb, y_pred_rbf):.4f}")

# Grid Search
param_grid = {
    'C': [0.1, 1, 10, 100],                         # Durezza del soft margin
    'gamma': ['scale', 'auto', 0.001, 0.01]         # Parametro di scala per il kernel RBF
}

grid_search = GridSearchCV(
    SVC(kernel='rbf', probability=True, random_state=42),
    param_grid,
    cv=5,
    scoring='f1',
    n_jobs=-1
)

grid_search.fit(X_trainval_cb, y_trainval_cb)

print(f"Migliori parametri: {grid_search.best_params_}")
print(f"Miglior F1 (CV): {grid_search.best_score_:.4f}")
print(f"Accuratezza incrememntata di: {grid_search.best_score_ - f1_score(y_test_cb, y_pred_rbf):.4f}")
# Out:
# SVM RBF Base - F1 Score: 0.8173
# Migliori parametri: {'C': 0.1, 'gamma': 'auto'}
# Miglior F1 (CV): 0.8259
# Accuratezza incrememntata di: 0.0087

# %%
# Valuazione del modello ottimizzato

# Modello ottimizzato
best_svm = grid_search.best_estimator_
y_pred_best = best_svm.predict(X_test_cb)

acc = accuracy_score(y_test_cb, y_pred_best)

print(f"Accuratezza SVM: {acc:.4f}")

# Visualizzazione
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Confusion Matrix
cm = confusion_matrix(y_test_cb, y_pred_best)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax1,
            xticklabels=['Predetto: 0', 'Predetto: 1'],
            yticklabels=['Reale: 0', 'Reale: 1'])
ax1.set_title('Matrice di Confusione - SVM Cannabis')

# ROC Curve
y_score = best_svm.predict_proba(X_test_cb)[:, 1]
fpr, tpr, _ = roc_curve(y_test_cb, y_score)

ax2.plot(fpr, tpr, color='darkorange', lw=2, 
         label=f'ROC curve')
ax2.plot([0, 1], [0, 1], 'k--', lw=2)
ax2.set_xlabel('False Positive Rate')
ax2.set_ylabel('True Positive Rate')
ax2.set_title('ROC Curve - SVM Cannabis')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Accuratezza SVM: 0.8304

# %%
# Confronto kernel diversi
kernels = {
    'RBF': SVC(kernel='rbf', C=grid_search.best_params_['C'], gamma=grid_search.best_params_['gamma'], probability=True, random_state=42),
    'Linear': SVC(kernel='linear', C=1.0, probability=True, random_state=42),
    'Poly': SVC(kernel='poly', degree=3, C=1.0, probability=True, random_state=42),
    'Sigmoid': SVC(kernel='sigmoid', C=1.0, probability=True, random_state=42)
}

kernel_results = []
for name, model in kernels.items():
    model.fit(X_trainval_cb, y_trainval_cb)
    y_pred = model.predict(X_test_cb)
    
    kernel_results.append({
        'Kernel': name,
        'Accuracy': accuracy_score(y_test_cb, y_pred)
    })

kernel_df = pd.DataFrame(kernel_results)
display(kernel_df.round(4))

# Grafico confronto
kernel_df.set_index('Kernel')['Accuracy'].plot(kind='bar', figsize=(8, 5))
plt.title('Confronto Performance Kernel SVM - Cannabis')
plt.ylabel('Accuracy')
plt.xticks(rotation=45)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
#     Kernel  Accuracy
# 0      RBF    0.8304
# 1   Linear    0.8233
# 2     Poly    0.8163
# 3  Sigmoid    0.7703

# %%
# Confronto finale MLP vs SVM
confronto_cannabis = pd.DataFrame({
    'Modello': ['MLP', 'SVM RBF Ottimizzato'],
    'Accuracy': [acc_test, acc]
})

display(confronto_cannabis.round(4))

# Visualizzazione confronto
fig, ax = plt.subplots(figsize=(8, 6))

mlp_acc = acc_test
svm_acc = acc

modelli = ['MLP', 'SVM RBF']
accuracies = [mlp_acc, svm_acc]

ax.bar(modelli, accuracies, alpha=0.8, color=['skyblue', 'orange'])
ax.set_ylabel('Accuracy')
ax.set_title('MLP vs SVM per Classificazione Cannabis')
ax.grid(True, alpha=0.3)


for i, v in enumerate(accuracies):
    ax.text(i, v + 0.01, f'{v:.3f}', ha='center', va='bottom')

plt.tight_layout()
plt.show()
# Out:
#                Modello  Accuracy
# 0                  MLP    0.8233
# 1  SVM RBF Ottimizzato    0.8304
